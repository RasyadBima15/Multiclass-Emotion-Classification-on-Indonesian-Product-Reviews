# %%
import requests
import json
import pandas as pd
import time
from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    precision_score,
    recall_score,
    f1_score,
    accuracy_score
)
import matplotlib.pyplot as plt
import seaborn as sns
from pynvml import *
import psutil
import os
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_17472\2238081627.py:16: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   from pynvml import *

# %%
try:
    df = pd.read_csv("../../../test_llm.csv")
except FileNotFoundError:
    print("Error: File 'test_llm.csv' not found.")
    print("Pastikan file tersebut berada di direktori yang sama dengan script ini.")

# %%
test_df = df.copy()
test_df['label_score'] = test_df['Emotion']

# %%
import os
import time
import json
import pandas as pd
from dotenv import load_dotenv, find_dotenv
import psutil
from openai import OpenAI

# =======================================================
# = LOAD API KEY
# =======================================================
dotenv_path = find_dotenv(usecwd=True, raise_error_if_not_found=False)
if dotenv_path:
    load_dotenv(dotenv_path)
else:
    print("⚠️ .env tidak ditemukan.")

client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

# =======================================================
# = RAM MONITOR
# =======================================================
def get_ram_usage_gb():
    return psutil.virtual_memory().used / (1024**3)

def get_vram_usage_gb():
    return 0.0  # Model cloud → VRAM 0

# =======================================================
# = PARAMETER
# =======================================================
emotion_labels = ["Anger", "Fear", "Happy", "Love", "Sadness"]
predictions = []
start_time = time.time()
PENDING_TIMEOUT = 5

model_name = "gpt-4.1-mini"

print(f"🚀 Mulai inferensi dengan model: {model_name}")
print("-" * 50)

# =======================================================
# = LOOP INFERENSI
# =======================================================
for i, row in test_df.iterrows():
    teks = row["Customer Review"]

    # SYSTEM PROMPT
    system_prompt = """
    Anda adalah asisten AI yang ahli dalam analisis emosi pada teks Bahasa Indonesia. 
    Tugas Anda adalah mengklasifikasikan teks pengguna ke dalam salah satu dari 
    5 kelas emosi berikut: Anger, Fear, Happy, Love, dan Sadness.

    Gunakan panduan karakteristik berikut:

    1. ANGER
    - Mengandung kata kasar atau makian.
    - Menunjukkan kemarahan, kekesalan, atau kebencian.
    - Keluhan atau ketidaksukaan terhadap produk/layanan/pengiriman.
    - Menggunakan huruf kapital berlebihan atau tanda baca marah (“!!!”, “???”).
    - Ekspresi jengkel, sebel, atau benci.

    2. FEAR
    - Kalimat peringatan atau rasa takut.
    - Kekhawatiran terhadap produk atau penjual.
    - Keraguan, ketidakpastian, atau menanyakan hal yang membuat cemas.
    - Ekspresi hati-hati, waspada, curiga, atau ragu terhadap keamanan.

    3. HAPPY
    - Mengandung pujian.
    - Kepuasan terhadap produk/penjual.
    - Ekspresi senang, gembira, bahagia, atau puas.
    - Bangga dan memberikan penilaian positif terhadap kualitas produk/penjual.

    4. LOVE
    - Ekspresi perasaan sayang, suka, atau rasa cinta.
    - Sangat puas terhadap produk.
    - Mengandung ungkapan hiperbola/“berlebihan” untuk menyanjung.
    - Mengandung pujian kuat atau kekaguman mendalam.
    - Ekspresi bangga atau sangat menyukai produk/penjual.

    5. SADNESS
    - Menyatakan kekecewaan terhadap produk.
    - Penyesalan, sedih, atau tidak puas.
    - Ekspresi kecewa, menyesal, atau merasa dirugikan.

    Keluaran Anda HARUS berupa JSON dengan format:
    {"emosi": "<Anger/Fear/Happy/Love/Sadness>"}
    """

    few_shot_examples = """
    Berikut adalah 5 contoh kasus klasifikasi emosi (5-SHOTS) beserta output JSON yang diharapkan. Model HARUS mengikuti format ini:

    --- Contoh 1 (Fear) ---
    Teks ulasan: "Barang tidak sesuai dengan yg di iklankan seperti nya bekas"
    Output: {"emosi": "Fear"}
    
    --- Contoh 2 (Happy) ---
    Teks ulasan: "pengiriman cepat, packing rapi, kualitas mantap"
    Output: {"emosi": "Happy"}

    --- Contoh 3 (Anger) ---
    Teks ulasan: "Barang Rusak , Ga Guna Sama Sekali ... Parah"
    Output: {"emosi": "Anger"}

    --- Contoh 4 (Love) ---
    Teks ulasan: "Bagus banget keyboardnya. Packing sangat aman karena double kardus. Warna juga keren."
    Output: {"emosi": "Love"}

    --- Contoh 5 (Sadness) ---
    Teks ulasan: "Kecewa parah nggk berkah jualan gitu"
    Output: {"emosi": "Sadness"}

    Klasifikasikan teks ulasan baru di bawah berdasarkan konteks 5 contoh di atas.
    """

    user_prompt = f"""
    {few_shot_examples}
    
    Teks ulasan berikut: 
    "{teks}"

    Klasifikasikan teks tersebut ke dalam salah satu emosi berikut:
    {', '.join(emotion_labels)}.
    """

    t0 = time.time()

    try:
        # ============================
        # REQUEST OPENAI API
        # ============================
        response = client.chat.completions.create(
            model=model_name,
            messages=[
                {"role": "system", "content": system_prompt},
                {"role": "user", "content": user_prompt},
            ],
            response_format={"type": "json_object"}
        )

        # Extract usage metadata
        usage = response.usage
        input_tokens = usage.prompt_tokens if usage else 0
        output_tokens = usage.completion_tokens if usage else 0

        # Parse JSON response
        assistant_text = response.choices[0].message.content.strip()

        try:
            hasil = json.loads(assistant_text)
        except json.JSONDecodeError:
            print(f"[{i}] ⚠️ Gagal parse JSON: {assistant_text}")
            continue

        emosi_pred = hasil.get("emosi", "").capitalize().strip()
        if emosi_pred not in emotion_labels:
            print(f"[{i}] ❌ Emosi tidak valid: {emosi_pred}, fallback → Neutral")
            emosi_pred = "Neutral"

        # Metrics
        latency = time.time() - t0
        ram_usage = get_ram_usage_gb()
        vram_usage = get_vram_usage_gb()

        predictions.append({
            "text": teks,
            "actual": row["Emotion"],
            "predicted": emosi_pred,
            "latency_sec": latency,
            "ram_gb": ram_usage,
            "vram_gb": vram_usage,
            "prompt_tokens": input_tokens,
            "completion_tokens": output_tokens,
        })

        print(f"[{i}] {teks[:50]} → {emosi_pred} | {latency:.2f}s | Tokens: {input_tokens}/{output_tokens}")

        # Delay 10 detik
        print(f"[{i}] 💤 Menunggu {PENDING_TIMEOUT} detik...")
        time.sleep(PENDING_TIMEOUT)

    except Exception as e:
        print(f"[{i}] ❌ Error API OpenAI: {e}")
        continue

# =======================================================
# = RINGKASAN
# =======================================================
end_time = time.time()
total_time = end_time - start_time

if predictions:
    latencies = [p["latency_sec"] for p in predictions]
    lat_no_first = latencies[1:] if len(latencies) > 1 else latencies
    avg_latency = sum(lat_no_first)/len(lat_no_first) if lat_no_first else 0
    throughput = (len(lat_no_first)/sum(lat_no_first))*60 if len(lat_no_first)>1 else 0

    avg_prompt_tokens = sum(p["prompt_tokens"] for p in predictions)/len(predictions)
    avg_completion_tokens = sum(p["completion_tokens"] for p in predictions)/len(predictions)

    avg_ram = sum(p["ram_gb"] for p in predictions)/len(predictions)
    avg_vram = sum(p["vram_gb"] for p in predictions)/len(predictions)

    print("\n" + "="*50)
    print("📊 RINGKASAN EVALUASI")
    print("="*50)
    print(f"Total sampel   : {len(predictions)}")
    print(f"Total waktu    : {total_time:.2f} detik")
    print(f"Avg latency    : {avg_latency:.2f} detik")
    print(f"Throughput     : {throughput:.2f} sampel/menit")
    print("-"*50)
    print(f"Rata2 Prompt Tokens     : {avg_prompt_tokens:.0f}")
    print(f"Rata2 Completion Tokens : {avg_completion_tokens:.0f}")
    print("-"*50)
    print(f"Rata2 RAM usage : {avg_ram:.2f} GB")

    # Simpan CSV
    results_df = pd.DataFrame(predictions)
    results_df.to_csv("results_metrics_emotion.csv", index=False)
    print("✅ Disimpan ke: results_metrics_emotion.csv")

else:
    print("❌ Tidak ada prediksi yang berhasil.")
# Out:
# 🚀 Mulai inferensi dengan model: gpt-4.1-mini
# --------------------------------------------------
# [0] buahnya bagus... kurirnya ok sellernya juga ok → Happy | 1.42s | Tokens: 779/7
# [0] 💤 Menunggu 5 detik...
# [1] Ada sedikit cacat, selainnya oke → Happy | 0.93s | Tokens: 774/7
# [1] 💤 Menunggu 5 detik...
# [2] Jadi semangat mancing. → Happy | 0.89s | Tokens: 772/7
# [2] 💤 Menunggu 5 detik...
# [3] Cepat tiba n kemasan bagus. barangnya juga bagus → Happy | 1.14s | Tokens: 778/7
# [3] 💤 Menunggu 5 detik...
# [4] Produk sesuai deskripsi??. Variasi produk beragam. → Happy | 0.86s | Tokens: 782/7
# [4] 💤 Menunggu 5 detik...
# [5] pelayanan memuaskan dan barang sesuai ?? → Happy | 0.99s | Tokens: 775/7
# [5] 💤 Menunggu 5 detik...
# [6] Barang bagus dan cepat sekali sampainya ke cianjur → Happy | 3.07s | Tokens: 785/7
# [6] 💤 Menunggu 5 detik...
# [7] Bagus mantab jernih → Love | 0.83s | Tokens: 773/7
# [7] 💤 Menunggu 5 detik...
# [8] trmksh barang sesuai pesanan, fungsi normal... tin → Happy | 0.81s | Tokens: 781/7
# [8] 💤 Menunggu 5 detik...
# [9] Green screen sudah nyampe, bahan cukup tebal, miri → Happy | 1.34s | Tokens: 800/7
# [9] 💤 Menunggu 5 detik...
# [10] lumayan lah, buat pemanasan → Happy | 0.92s | Tokens: 773/7
# [10] 💤 Menunggu 5 detik...
# [11] paking rapih, kondisi barang datang mantap. kualit → Happy | 2.10s | Tokens: 783/7
# [11] 💤 Menunggu 5 detik...
# [12] produk asli original. suplemen bagus tanpa efek sa → Happy | 1.21s | Tokens: 794/7
# [12] 💤 Menunggu 5 detik...
# [13] barang bagus dan layanan bagus → Happy | 0.76s | Tokens: 771/7
# [13] 💤 Menunggu 5 detik...
# [14] untuk harga sgitu bolehlah, dan penjual juga menje → Happy | 0.85s | Tokens: 788/7
# [14] 💤 Menunggu 5 detik...
# [15] Cepet nyampe, seller oke → Happy | 0.78s | Tokens: 773/7
# [15] 💤 Menunggu 5 detik...
# [16] barang sdh nyampe dgn baik. senang banget terima p → Happy | 0.74s | Tokens: 808/7
# [16] 💤 Menunggu 5 detik...
# [17] Kainnya gk tipis, standar tebal batik biasa, adem  → Happy | 0.96s | Tokens: 794/7
# [17] 💤 Menunggu 5 detik...
# [18] Barusan saya tes untuk ambil sampah di sungai deka → Happy | 0.76s | Tokens: 828/7
# [18] 💤 Menunggu 5 detik...
# [19] alhamdulillah, produk ini sangat membantu. yang bi → Love | 0.76s | Tokens: 1003/7
# [19] 💤 Menunggu 5 detik...
# [20] sesuai dengan pesanan, bahan halus, kayaknya adem. → Happy | 0.82s | Tokens: 780/7
# [20] 💤 Menunggu 5 detik...
# [21] sudah terima packingnya rapi, bahannya lembut, ena → Happy | 0.81s | Tokens: 799/7
# [21] 💤 Menunggu 5 detik...
# [22] Barang Sesuai Deskripsi. Produk Original. Packagin → Happy | 0.77s | Tokens: 779/7
# [22] 💤 Menunggu 5 detik...
# [23] mantap, bagus dan teba → Happy | 0.71s | Tokens: 773/7
# [23] 💤 Menunggu 5 detik...
# [24] Sesuai deskripsi dan pesanan. Terimakasih → Happy | 0.76s | Tokens: 779/7
# [24] 💤 Menunggu 5 detik...
# [25] Produk Sesuai. Material Produk Bagus. Cocok untuk  → Happy | 0.83s | Tokens: 805/7
# [25] 💤 Menunggu 5 detik...
# [26] wae keren. alatnya berasa jadi pengrajin rokok. ma → Love | 1.13s | Tokens: 795/7
# [26] 💤 Menunggu 5 detik...
# [27] Bagus dan ini order saya yang kedua. → Happy | 0.76s | Tokens: 774/7
# [27] 💤 Menunggu 5 detik...
# [28] Teksturnya creamy. Gampang dipakai. Packaging aman → Happy | 0.84s | Tokens: 780/7
# [28] 💤 Menunggu 5 detik...
# [29] masker bagus,sesuai harga` → Happy | 0.73s | Tokens: 774/7
# [29] 💤 Menunggu 5 detik...
# [30] bagus banget bahan nya juga adem ini bakal jadi la → Love | 0.83s | Tokens: 788/7
# [30] 💤 Menunggu 5 detik...
# [31] respon baik mutu lumayan hrg terjangkau → Happy | 1.01s | Tokens: 777/7
# [31] 💤 Menunggu 5 detik...
# [32] Kualitas Produk Bagus. Produk Sesuai → Happy | 0.80s | Tokens: 776/7
# [32] 💤 Menunggu 5 detik...
# [33] Bahan bagus, kain bisa melebar dan elastis → Love | 0.73s | Tokens: 777/7
# [33] 💤 Menunggu 5 detik...
# [34] Cepat, rapih dan aman. Saya mau beli lagi nanti ya → Happy | 0.83s | Tokens: 780/7
# [34] 💤 Menunggu 5 detik...
# [35] Cepat dan packing amanah bgt.kualitas susu sdh ter → Happy | 1.17s | Tokens: 789/7
# [35] 💤 Menunggu 5 detik...
# [36] barang telah sampai dengan packaging yg bagus → Happy | 1.13s | Tokens: 773/7
# [36] 💤 Menunggu 5 detik...
# [37] ukurannya ada yg besar ada yg kecil tapi lumayan d → Happy | 2.59s | Tokens: 786/7
# [37] 💤 Menunggu 5 detik...
# [38] bagus, bisa nempel di kayu → Happy | 0.77s | Tokens: 775/7
# [38] 💤 Menunggu 5 detik...
# [39] alhamdulillah barang sampai di tgl 6/11. Isi dusny → Happy | 0.79s | Tokens: 819/7
# [39] 💤 Menunggu 5 detik...
# [40] Jahitannya rapi. Warnanya cantik ??. Bahannya lemb → Love | 0.73s | Tokens: 801/7
# [40] 💤 Menunggu 5 detik...
# [41] Mantap keren. Cuma harus colok listrik kalau mau p → Happy | 0.85s | Tokens: 803/7
# [41] 💤 Menunggu 5 detik...
# [42] Pertama x custom dan hasil ny sesuai request → Happy | 0.75s | Tokens: 775/7
# [42] 💤 Menunggu 5 detik...
# [43] mantap paten joss → Happy | 0.83s | Tokens: 772/7
# [43] 💤 Menunggu 5 detik...
# [44] packing rapih aman makasih → Happy | 0.77s | Tokens: 773/7
# [44] 💤 Menunggu 5 detik...
# [45] warnanya ga sesuai photo di deskripsi warna sepatu → Sadness | 0.83s | Tokens: 791/8
# [45] 💤 Menunggu 5 detik...
# [46] Ada 1 shade yg salah kirim → Sadness | 0.85s | Tokens: 774/8
# [46] 💤 Menunggu 5 detik...
# [47] barang biasa aja ...bahan kurang bgitu bagus → Sadness | 1.04s | Tokens: 776/8
# [47] 💤 Menunggu 5 detik...
# [48] Jahitannya berantakan banget. gak kenceng aku beny → Sadness | 0.84s | Tokens: 795/8
# [48] 💤 Menunggu 5 detik...
# [49] bahan ny sih bagus, cm sayang pesen nya 2 datang n → Anger | 0.85s | Tokens: 817/8
# [49] 💤 Menunggu 5 detik...
# [50] Packingnya cm kresek krg aman, jd pas dateng peot  → Sadness | 0.90s | Tokens: 791/8
# [50] 💤 Menunggu 5 detik...
# [51] Kecewa dengan waktu pengiriman. Order jam 11.52 se → Sadness | 0.78s | Tokens: 853/8
# [51] 💤 Menunggu 5 detik...
# [52] Dlm ordernya sdh sy tambah 'bubble wrap' (+ rp 10. → Anger | 0.75s | Tokens: 818/8
# [52] 💤 Menunggu 5 detik...
# [53] bungkusan barang robek, ada bagian kertas yg sudah → Sadness | 1.20s | Tokens: 795/8
# [53] 💤 Menunggu 5 detik...
# [54] balonnya kecil sekali ga sesuai gambar..ga bagus k → Sadness | 0.72s | Tokens: 788/8
# [54] 💤 Menunggu 5 detik...
# [55] Batre tidak sesuai ukuran dan tidak ada nano recei → Sadness | 0.80s | Tokens: 776/8
# [55] 💤 Menunggu 5 detik...
# [56] overpriced.. analisanya kurang dalam. kualitas har → Anger | 0.71s | Tokens: 789/8
# [56] 💤 Menunggu 5 detik...
# [57] boros batre → Sadness | 1.17s | Tokens: 770/8
# [57] 💤 Menunggu 5 detik...
# [58] yg micro ini sering rusak coba di tingkatkn lg kua → Anger | 0.80s | Tokens: 779/8
# [58] 💤 Menunggu 5 detik...
# [59] sambungannya tidak rapih.. → Sadness | 1.24s | Tokens: 774/8
# [59] 💤 Menunggu 5 detik...
# [60] Barang sampai dengan selamat, mic berfungsi tapi e → Sadness | 0.86s | Tokens: 789/8
# [60] 💤 Menunggu 5 detik...
# [61] kurang bagus → Sadness | 0.78s | Tokens: 769/8
# [61] 💤 Menunggu 5 detik...
# [62] model lumayan kren tapi kecewa di batre senternya  → Sadness | 1.80s | Tokens: 789/8
# [62] 💤 Menunggu 5 detik...
# [63] tidak berfugsi → Sadness | 0.85s | Tokens: 772/8
# [63] 💤 Menunggu 5 detik...
# [64] Baru seminggu pemakaian sudah tidak bisa nyala seb → Sadness | 1.22s | Tokens: 781/8
# [64] 💤 Menunggu 5 detik...
# [65] Barang gak berfungsi, kalo mau dikirim cek dulu bo → Anger | 0.81s | Tokens: 803/8
# [65] 💤 Menunggu 5 detik...
# [66] barang dikrm beda dgn yg pesan → Sadness | 0.85s | Tokens: 774/8
# [66] 💤 Menunggu 5 detik...
# [67] Beli 3 barang, hanya dikirim 2. Saat komplain dija → Sadness | 0.73s | Tokens: 826/8
# [67] 💤 Menunggu 5 detik...
# [68] Barang yang sampai cacat, tidak ngisi baterai stic → Sadness | 0.77s | Tokens: 779/8
# [68] 💤 Menunggu 5 detik...
# [69] Sangat kecewa dengan barang yg di terima segel Sam → Fear | 0.78s | Tokens: 911/7
# [69] 💤 Menunggu 5 detik...
# [70] Paking tidak rapih jebol → Anger | 0.87s | Tokens: 773/8
# [70] 💤 Menunggu 5 detik...
# [71] Ada kekecewaan ketika lihat brg datang.....Aq piki → Sadness | 0.79s | Tokens: 823/8
# [71] 💤 Menunggu 5 detik...
# [72] kecewa dengan pelayanan toko ini, Dan nyesal denga → Sadness | 0.91s | Tokens: 822/8
# [72] 💤 Menunggu 5 detik...
# [73] barang dibungkus pakai bubblewarp, trs pecah gatau → Sadness | 0.90s | Tokens: 805/8
# [73] 💤 Menunggu 5 detik...
# [74] ujung buku rusak.. padahal sudah mahal beli buku i → Sadness | 0.73s | Tokens: 779/8
# [74] 💤 Menunggu 5 detik...
# [75] baru pakai beberapa kali, sponnya terpisah jadi 3, → Sadness | 0.81s | Tokens: 786/8
# [75] 💤 Menunggu 5 detik...
# [76] ukurannya tidak sesuai..pesan 5x7 dikirim 4x6 → Sadness | 0.77s | Tokens: 783/8
# [76] 💤 Menunggu 5 detik...
# [77] Suaranya gk bs bersih. Ada noise. Hasilnya lebih b → Sadness | 0.75s | Tokens: 795/8
# [77] 💤 Menunggu 5 detik...
# [78] Padahal udah tanya sebelumnya sama penjualnya ada  → Sadness | 0.91s | Tokens: 840/8
# [78] 💤 Menunggu 5 detik...
# [79] belom 1 bulan udah gak nyala, baterai udah diganti → Sadness | 0.81s | Tokens: 803/8
# [79] 💤 Menunggu 5 detik...
# [80] Packing kurang rapih, pinggir buku menjadi rusak → Sadness | 1.05s | Tokens: 777/8
# [80] 💤 Menunggu 5 detik...
# [81] Bahan sangat mudah bengkok pdhl hanya sepatu & sam → Sadness | 1.18s | Tokens: 783/8
# [81] 💤 Menunggu 5 detik...
# [82] infra red nya jelek suka mental ke mana2 → Anger | 0.73s | Tokens: 776/8
# [82] 💤 Menunggu 5 detik...
# [83] lambat → Anger | 1.03s | Tokens: 769/8
# [83] 💤 Menunggu 5 detik...
# [84] tipis bgt → Sadness | 0.84s | Tokens: 770/8
# [84] 💤 Menunggu 5 detik...
# [85] kecewa sekali ada 10 lembar warnanya beda memang s → Sadness | 0.78s | Tokens: 807/8
# [85] 💤 Menunggu 5 detik...
# [86] kacamata sangat rentan. dipakai sekali patah. kare → Sadness | 1.08s | Tokens: 799/8
# [86] 💤 Menunggu 5 detik...
# [87] Packing tdk ada, sudah tau pengiriman jauh tp tdk  → Anger | 1.24s | Tokens: 794/8
# [87] 💤 Menunggu 5 detik...
# [88] kecewa bagt. barang yg di kirim tidak sesuai. masi → Sadness | 2.08s | Tokens: 808/8
# [88] 💤 Menunggu 5 detik...
# [89] saya sangat kecewa belanja di toko ini. respon pen → Sadness | 1.24s | Tokens: 815/8
# [89] 💤 Menunggu 5 detik...
# [90] wah sy pake sameday..masa dtgnya besoknya. smtra s → Anger | 1.26s | Tokens: 825/8
# [90] 💤 Menunggu 5 detik...
# [91] mohon maaf dikasih rating segini, karena barang yg → Sadness | 0.80s | Tokens: 812/8
# [91] 💤 Menunggu 5 detik...
# [92] pembelian ke 2 beda 10 hari aja, kenapa pelet maxi → Fear | 1.29s | Tokens: 801/7
# [92] 💤 Menunggu 5 detik...
# [93] Barangnya ga ada → Sadness | 0.77s | Tokens: 770/8
# [93] 💤 Menunggu 5 detik...
# [94] Bahan plastiknya tdk stretch, kaku dan tidak bagus → Anger | 1.36s | Tokens: 795/8
# [94] 💤 Menunggu 5 detik...
# [95] bad admin. Opportunity lost gara2 mau tambah pesan → Anger | 0.78s | Tokens: 792/8
# [95] 💤 Menunggu 5 detik...
# [96] PO udah sebulan gak sampai cm d kirim voucher dan  → Anger | 0.81s | Tokens: 816/8
# [96] 💤 Menunggu 5 detik...
# [97] Pengirimannya sih cepat, tapi barangnya bruntusan  → Sadness | 0.83s | Tokens: 836/8
# [97] 💤 Menunggu 5 detik...
# [98] kemasan hancurrr pecah berantakan... ga jadi kepak → Sadness | 0.75s | Tokens: 794/8
# [98] 💤 Menunggu 5 detik...
# [99] pengiriman pertama sudah expired. barang diganti b → Sadness | 0.75s | Tokens: 805/8
# [99] 💤 Menunggu 5 detik...
# [100] tidak sesuai → Sadness | 0.80s | Tokens: 769/8
# [100] 💤 Menunggu 5 detik...
# [101] Miniboxnya sih ok lampu led berfungsi dan menyala  → Anger | 3.00s | Tokens: 872/8
# [101] 💤 Menunggu 5 detik...
# [102] barang datang tidak lengkap. yidak akan pernah bel → Anger | 1.09s | Tokens: 784/8
# [102] 💤 Menunggu 5 detik...
# [103] Hari ini baru terpasang. Ternyata ada satu palang  → Sadness | 1.21s | Tokens: 831/8
# [103] 💤 Menunggu 5 detik...
# [104] Admin toko ini tdk punya sopan santun, bukannya ca → Anger | 0.83s | Tokens: 807/8
# [104] 💤 Menunggu 5 detik...
# [105] gk ada plat besinya...cm ada label merk bahan → Sadness | 0.78s | Tokens: 778/8
# [105] 💤 Menunggu 5 detik...
# [106] Iklannya Seragam PGRI Kemeja Hem Katun Pria. Tp te → Sadness | 0.74s | Tokens: 809/8
# [106] 💤 Menunggu 5 detik...
# [107] packaging gk aman bgt, bubble wrap tipis alhasil k → Fear | 0.70s | Tokens: 811/7
# [107] 💤 Menunggu 5 detik...
# [108] barangnya gak sesuai gambar, biasa aja, pantes hrg → Sadness | 0.76s | Tokens: 780/8
# [108] 💤 Menunggu 5 detik...
# [109] kartu tidak terdeteksi jadi jam gk cocok, sudah co → Sadness | 2.60s | Tokens: 801/8
# [109] 💤 Menunggu 5 detik...
# [110] Produk nya bocor karena packing nya krg bgs. Dr du → Sadness | 0.80s | Tokens: 817/8
# [110] 💤 Menunggu 5 detik...
# [111] Barang yang dikirimkan tidak sesuai dengan orderan → Anger | 0.94s | Tokens: 856/8
# [111] 💤 Menunggu 5 detik...
# [112] Koneksi perangkat susah, kalaupun konek seringkali → Sadness | 0.82s | Tokens: 807/8
# [112] 💤 Menunggu 5 detik...
# [113] tidak recommend banget pelayanan ngk bagus dan tid → Anger | 0.81s | Tokens: 792/8
# [113] 💤 Menunggu 5 detik...
# [114] barang tidak sampai. tdk ada solusi → Anger | 0.83s | Tokens: 774/8
# [114] 💤 Menunggu 5 detik...
# [115] beli 5 pd gosong semua.??baru apa bekas nih? biasa → Anger | 3.84s | Tokens: 796/8
# [115] 💤 Menunggu 5 detik...
# [116] bukan soal uangnya ,tapi soal ke amanahannya. kiri → Anger | 0.83s | Tokens: 851/8
# [116] 💤 Menunggu 5 detik...
# [117] baunya pasaran, prtama kali pakai semua orang seki → Sadness | 0.78s | Tokens: 800/8
# [117] 💤 Menunggu 5 detik...
# [118] Pesanan tidak dikirim, tidak ada komunikasi apapun → Anger | 0.74s | Tokens: 787/8
# [118] 💤 Menunggu 5 detik...
# [119] sangat kecewa belanja disini, response sangat lamb → Sadness | 0.81s | Tokens: 811/8
# [119] 💤 Menunggu 5 detik...
# [120] mesin kasar, pelayanan kurang → Anger | 0.79s | Tokens: 772/8
# [120] 💤 Menunggu 5 detik...
# [121] packingnya kurang memuaskan → Sadness | 0.77s | Tokens: 772/8
# [121] 💤 Menunggu 5 detik...
# [122] dipakai untuk mindahin tabung gas 12 kg sangat ser → Sadness | 0.82s | Tokens: 824/8
# [122] 💤 Menunggu 5 detik...
# [123] Sy order 5pcs dikirim cuma 4, Krn weekend senin sy → Anger | 0.80s | Tokens: 808/8
# [123] 💤 Menunggu 5 detik...
# [124] untuk jepit ke mejanya loss. ga bisa ngunci. sudah → Sadness | 0.93s | Tokens: 821/8
# [124] 💤 Menunggu 5 detik...
# [125] Parah ini toko ga ada tanggung jawab nya → Anger | 0.75s | Tokens: 776/8
# [125] 💤 Menunggu 5 detik...
# [126] Waktu sampai nya lakban Tokopedia di saya sangat l → Anger | 0.74s | Tokens: 807/8
# [126] 💤 Menunggu 5 detik...
# [127] Ternyata tidak sesuai. Tidak dpat dipakai → Sadness | 0.77s | Tokens: 777/8
# [127] 💤 Menunggu 5 detik...
# [128] beli 2 dipakai dua hari udah hangus. kapok beli di → Anger | 0.83s | Tokens: 795/8
# [128] 💤 Menunggu 5 detik...
# [129] Sudah kuduga kalau beli banyak, pasti ada beberapa → Anger | 1.24s | Tokens: 853/8
# [129] 💤 Menunggu 5 detik...
# [130] Barang baru diterima dicoba ternyata sudah rusak,  → Sadness | 1.20s | Tokens: 847/8
# [130] 💤 Menunggu 5 detik...
# [131] bukan dendeng daging sapi asli, semacam campuran → Sadness | 1.65s | Tokens: 779/8
# [131] 💤 Menunggu 5 detik...
# [132] beli 10pcs hampir rusak semua bentuknya, dan toko  → Anger | 1.18s | Tokens: 795/8
# [132] 💤 Menunggu 5 detik...
# [133] Barangnya tidak seperti barang baru dan tanpa kema → Fear | 1.25s | Tokens: 778/7
# [133] 💤 Menunggu 5 detik...
# [134] Gak sesuai gambar disitu gulanya yg hijau kenapa d → Sadness | 1.36s | Tokens: 816/8
# [134] 💤 Menunggu 5 detik...
# [135] Fastresp banget, ramah juga, pengirimannya gercep  → Happy | 1.55s | Tokens: 811/7
# [135] 💤 Menunggu 5 detik...
# [136] wow wow sangaat praktis euy, tapi emang harganya m → Love | 1.21s | Tokens: 799/7
# [136] 💤 Menunggu 5 detik...
# [137] puas banget ???????????????? → Love | 1.13s | Tokens: 773/7
# [137] 💤 Menunggu 5 detik...
# [138] mantaaaaaaaaapppppp pelayanan cepat pengirimannya. → Love | 0.91s | Tokens: 798/7
# [138] 💤 Menunggu 5 detik...
# [139] Mienya enak Favorit keluarga. Sudah langganan beli → Love | 0.76s | Tokens: 801/7
# [139] 💤 Menunggu 5 detik...
# [140] barang bagus..Bahannya adem. Modelnya cantik ??. → Happy | 1.07s | Tokens: 778/7
# [140] 💤 Menunggu 5 detik...
# [141] reoderrrrr → Anger | 0.82s | Tokens: 771/8
# [141] 💤 Menunggu 5 detik...
# [142] Seller ramah dan fast response. Packaging rapih da → Happy | 0.78s | Tokens: 786/7
# [142] 💤 Menunggu 5 detik...
# [143] Produk sesuai, pengiriman cepat, packing aman, rec → Happy | 1.20s | Tokens: 779/7
# [143] 💤 Menunggu 5 detik...
# [144] Instalasi Mudah. pengiriman cpt. respon cpt, trims → Happy | 1.10s | Tokens: 797/7
# [144] 💤 Menunggu 5 detik...
# [145] Sudah order yg kedua disini, packingnya rapi, untu → Happy | 1.49s | Tokens: 856/7
# [145] 💤 Menunggu 5 detik...
# [146] begitu datang ini langsung dicobain, semua berfung → Love | 0.76s | Tokens: 827/7
# [146] 💤 Menunggu 5 detik...
# [147] Recommended Seller!! Respon cepat, pengiriman cuku → Happy | 1.14s | Tokens: 777/7
# [147] 💤 Menunggu 5 detik...
# [148] jangan lupa gaes diorder toko ini → Happy | 0.81s | Tokens: 775/7
# [148] 💤 Menunggu 5 detik...
# [149] Puas sih.. Recomended bukunya → Happy | 0.85s | Tokens: 775/7
# [149] 💤 Menunggu 5 detik...
# [150] paaaaas banget ukurannya buat gantiin tempat sampa → Love | 0.82s | Tokens: 812/7
# [150] 💤 Menunggu 5 detik...
# [151] bagus bgt bukunya. suka. makasih → Love | 0.94s | Tokens: 778/7
# [151] 💤 Menunggu 5 detik...
# [152] BAGUUUSSSS PACKING RAPUI, CEPAT SAMPAI, TERIMAKASI → Love | 1.26s | Tokens: 797/7
# [152] 💤 Menunggu 5 detik...
# [153] check in nya gampang bgt, cuma kasih liat aja invo → Happy | 1.19s | Tokens: 794/7
# [153] 💤 Menunggu 5 detik...
# [154] Bahannya adem. Warnanya cantik ??. Ukuran sesuai.  → Happy | 1.27s | Tokens: 784/7
# [154] 💤 Menunggu 5 detik...
# [155] Suka sama box nya ciamik dehhhhhhhhhhhhhhhhhhhhh → Love | 1.16s | Tokens: 781/7
# [155] 💤 Menunggu 5 detik...
# [156] order yang ketiga. gercep. barang oke. pelayanan j → Happy | 1.05s | Tokens: 780/7
# [156] 💤 Menunggu 5 detik...
# [157] packing rapih, fast response, dan rgbnya juga bagu → Love | 1.04s | Tokens: 789/7
# [157] 💤 Menunggu 5 detik...
# [158] Selalu the best bgt deh... anabul ngga usah di tra → Love | 1.18s | Tokens: 787/7
# [158] 💤 Menunggu 5 detik...
# [159] mantappppppppppppppppppppppppppppppppp → Love | 0.85s | Tokens: 784/7
# [159] 💤 Menunggu 5 detik...
# [160] Build quality cakep,,stik normal smua,,pengiriman  → Love | 0.75s | Tokens: 792/7
# [160] 💤 Menunggu 5 detik...
# [161] Produk yang diterima lengkap. Pas di kepala. Lampu → Happy | 0.73s | Tokens: 789/7
# [161] 💤 Menunggu 5 detik...
# [162] So far kualitas dan bentuk pellet paling bagus dar → Love | 0.87s | Tokens: 797/7
# [162] 💤 Menunggu 5 detik...
# [163] Orderan yg ke 3 kali, selalu puas, unit bor nya ma → Happy | 0.86s | Tokens: 797/7
# [163] 💤 Menunggu 5 detik...
# [164] langganan beli minigold disini ?? → Happy | 0.79s | Tokens: 776/7
# [164] 💤 Menunggu 5 detik...
# [165] suka banget sama original source yang mint → Love | 0.92s | Tokens: 774/7
# [165] 💤 Menunggu 5 detik...
# [166] game lancar, kondisi box dan game cartridges mulus → Love | 0.89s | Tokens: 797/7
# [166] 💤 Menunggu 5 detik...
# [167] Mantapppp.Build qualitynya josss Pertahankan → Love | 0.74s | Tokens: 778/7
# [167] 💤 Menunggu 5 detik...
# [168] mantap. pengiriman nya cepat banget. barang oke se → Love | 0.84s | Tokens: 801/7
# [168] 💤 Menunggu 5 detik...
# [169] alhmdllh pkt ny dah smpe..ank2 seneng bgt klu Maka → Happy | 0.89s | Tokens: 798/7
# [169] 💤 Menunggu 5 detik...
# [170] Pengiriman cepat dan aman. Barang sesuai deskripsi → Happy | 1.16s | Tokens: 829/7
# [170] 💤 Menunggu 5 detik...
# [171] manchapppp.. sy suka. rekomen seller.. → Love | 0.80s | Tokens: 778/7
# [171] 💤 Menunggu 5 detik...
# [172] Mantap donk. Produk Original. → Happy | 1.66s | Tokens: 773/7
# [172] 💤 Menunggu 5 detik...
# [173] mantul boskuhhh barang istimewa → Love | 0.75s | Tokens: 775/7
# [173] 💤 Menunggu 5 detik...
# [174] Suka dengan bardi ini. Membantu banget matiin bebe → Love | 0.78s | Tokens: 820/7
# [174] 💤 Menunggu 5 detik...
# [175] lucu bgt warnanya. recommended harga murah tapi ng → Love | 3.23s | Tokens: 786/7
# [175] 💤 Menunggu 5 detik...
# [176] Respond seller cepat, pengiriman segera. Produk be → Love | 0.86s | Tokens: 781/7
# [176] 💤 Menunggu 5 detik...
# [177] mantappppp → Happy | 0.75s | Tokens: 770/7
# [177] 💤 Menunggu 5 detik...
# [178] pohonnya masih segar, bonusnya juga banyak. makasi → Happy | 0.75s | Tokens: 792/7
# [178] 💤 Menunggu 5 detik...
# [179] Selalu bagus produknya, pembelian ke 2 Mantapp min → Love | 0.89s | Tokens: 786/7
# [179] 💤 Menunggu 5 detik...
# [180] Konsumen ga dianggap... Attitude merupakan hal pok → Anger | 1.02s | Tokens: 788/8
# [180] 💤 Menunggu 5 detik...
# [181] GA DIKASIH ADAPTOR GEPENG NYA. KETIPU SAYA → Anger | 1.26s | Tokens: 786/8
# [181] 💤 Menunggu 5 detik...
# [182] packaging kurang rapih, semua kemasan produk BOLT  → Anger | 0.75s | Tokens: 791/8
# [182] 💤 Menunggu 5 detik...
# [183] Rasanya ngadi2 sumpah, kayak pake saos sambel ?? k → Anger | 0.80s | Tokens: 824/8
# [183] 💤 Menunggu 5 detik...
# [184] penjual gk respon bgt parah → Anger | 1.55s | Tokens: 775/8
# [184] 💤 Menunggu 5 detik...
# [185] orng nnya responnya jutek bgt,, biasa aja kali, sa → Anger | 1.23s | Tokens: 801/8
# [185] 💤 Menunggu 5 detik...
# [186] barang yg dikirim gk sesuai modelnya → Fear | 1.23s | Tokens: 775/7
# [186] 💤 Menunggu 5 detik...
# [187] Barang mau dikirim pakai ekspedisi ke luar kota ta → Anger | 1.22s | Tokens: 795/8
# [187] 💤 Menunggu 5 detik...
# [188] aromanya bikin pusing dan mual → Sadness | 1.20s | Tokens: 775/8
# [188] 💤 Menunggu 5 detik...
# [189] lubang nya jelek bgt → Anger | 1.70s | Tokens: 773/8
# [189] 💤 Menunggu 5 detik...
# [190] seller tidak bertanggung jawab. ???? → Anger | 1.29s | Tokens: 773/8
# [190] 💤 Menunggu 5 detik...
# [191] alamak....buset.packingnya kurang rapi...di bungku → Anger | 0.76s | Tokens: 800/8
# [191] 💤 Menunggu 5 detik...
# [192] bohong. Sama sekali tidak manjur. → Anger | 0.98s | Tokens: 774/8
# [192] 💤 Menunggu 5 detik...
# [193] Beli 6 cuma dikirim 5, males complain ?? → Anger | 0.99s | Tokens: 779/8
# [193] 💤 Menunggu 5 detik...
# [194] palsu ya. g berfungsi. bahan kasar dan sakit kalo  → Anger | 0.89s | Tokens: 783/8
# [194] 💤 Menunggu 5 detik...
# [195] Chatt, hampir Ga ada respond → Anger | 0.80s | Tokens: 773/8
# [195] 💤 Menunggu 5 detik...
# [196] kurang 1, penjual kurang teliti atau sengaja. → Anger | 0.88s | Tokens: 779/8
# [196] 💤 Menunggu 5 detik...
# [197] kualitas barang dibanding harga nya hanya so so la → Anger | 0.81s | Tokens: 863/8
# [197] 💤 Menunggu 5 detik...
# [198] lama banget sampenya..pas nyampe jamuran gini..had → Anger | 0.80s | Tokens: 787/8
# [198] 💤 Menunggu 5 detik...
# [199] yg di pesan warna ngga sesuai klu memang ngga ada  → Anger | 0.88s | Tokens: 795/8
# [199] 💤 Menunggu 5 detik...
# [200] Roti keras gak enak → Anger | 0.84s | Tokens: 772/8
# [200] 💤 Menunggu 5 detik...
# [201] udang red bee yg dipesan tdk ada,sdh dikomplain ma → Anger | 0.81s | Tokens: 794/8
# [201] 💤 Menunggu 5 detik...
# [202] l2 r2 trigger nya ampas macam *** → Anger | 0.80s | Tokens: 776/8
# [202] 💤 Menunggu 5 detik...
# [203] bocor!! paket basah, jd tinggal bublrwrap terikat  → Anger | 0.81s | Tokens: 806/8
# [203] 💤 Menunggu 5 detik...
# [204] Barang dateng pake kurir toko, di unboxing trnyt a → Anger | 0.77s | Tokens: 856/8
# [204] 💤 Menunggu 5 detik...
# [205] cepet rusak, kadang konek kadang engga → Sadness | 0.91s | Tokens: 779/8
# [205] 💤 Menunggu 5 detik...
# [206] order minggu sampainya rabu, lambat nya minta ampu → Anger | 0.86s | Tokens: 816/8
# [206] 💤 Menunggu 5 detik...
# [207] BARANG TIDAK SESUAI PESANAN.. DIMINTA GOLD MALAH D → Anger | 0.87s | Tokens: 798/8
# [207] 💤 Menunggu 5 detik...
# [208] SALAH ALAMAT. Sudah saya kirim chat bahwa minta di → Anger | 0.83s | Tokens: 845/8
# [208] 💤 Menunggu 5 detik...
# [209] DUANYA LAGI GOIB → Anger | 0.86s | Tokens: 774/8
# [209] 💤 Menunggu 5 detik...
# [210] yg dikirim russakkkkk guys ampun dahh → Anger | 0.73s | Tokens: 777/8
# [210] 💤 Menunggu 5 detik...
# [211] ga sesuai expetasi.....barang2 nya ga kuat.ukuran  → Sadness | 0.74s | Tokens: 784/8
# [211] 💤 Menunggu 5 detik...
# [212] masa baru dateng langsung rusak → Anger | 0.88s | Tokens: 773/8
# [212] 💤 Menunggu 5 detik...
# [213] penyok, packingnya juga kurang aman → Sadness | 1.23s | Tokens: 775/8
# [213] 💤 Menunggu 5 detik...
# [214] KIRIM PAKET GA NGOTAK.. RESOLUSI ARBITER TOKOPEDIA → Anger | 1.55s | Tokens: 791/8
# [214] 💤 Menunggu 5 detik...
# [215] barang kualitas jelek, kaki patah, banyak pecah se → Anger | 0.82s | Tokens: 799/8
# [215] 💤 Menunggu 5 detik...
# [216] packing hanya buble wrap, lain kali tambahkan kard → Anger | 0.80s | Tokens: 812/8
# [216] 💤 Menunggu 5 detik...
# [217] Susah bgt pasangnya!!! Gak kuat menahan airnya!!! → Anger | 1.22s | Tokens: 781/8
# [217] 💤 Menunggu 5 detik...
# [218] Busa doank, tidak saya rekomendasikan → Anger | 1.23s | Tokens: 776/8
# [218] 💤 Menunggu 5 detik...
# [219] Chat tidak di balas, Kuota yang di janjikan 50gb n → Anger | 0.77s | Tokens: 794/8
# [219] 💤 Menunggu 5 detik...
# [220] Parah respon nya Butuh 4 hr sejak order baru dikir → Anger | 0.74s | Tokens: 788/8
# [220] 💤 Menunggu 5 detik...
# [221] buruk super duper buruk kok bisa rusakk dlm nya in → Anger | 0.86s | Tokens: 814/8
# [221] 💤 Menunggu 5 detik...
# [222] kw kirim brg bekas dan rusak serta tdk menerima ko → Anger | 0.80s | Tokens: 794/8
# [222] 💤 Menunggu 5 detik...
# [223] Jualan kok ngotottt, nggak laku toko nya bang? → Anger | 0.89s | Tokens: 782/8
# [223] 💤 Menunggu 5 detik...
# [224] bocor payahlah ga di periksa dulu → Anger | 0.76s | Tokens: 777/8
# [224] 💤 Menunggu 5 detik...
#
# ==================================================
# 📊 RINGKASAN EVALUASI
# ==================================================
# Total sampel   : 225
# Total waktu    : 1350.33 detik
# Avg latency    : 1.00 detik
# Throughput     : 60.08 sampel/menit
# --------------------------------------------------
# Rata2 Prompt Tokens     : 794
# Rata2 Completion Tokens : 8
# --------------------------------------------------
# Rata2 RAM usage : 13.22 GB
# ✅ Disimpan ke: results_metrics_emotion.csv

# %%
results_df = pd.read_csv('results_metrics_emotion.csv')

# %%
y_true = results_df["actual"]
y_pred = results_df["predicted"]

# %%
report = classification_report(y_true, y_pred, digits=2, zero_division=0)
print("\n=== CLASSIFICATION REPORT ===")
print(report)
# Out:
# === CLASSIFICATION REPORT ===
#               precision    recall  f1-score   support
#
#        Anger       0.57      0.89      0.70        45
#         Fear       0.60      0.07      0.12        45
#        Happy       0.66      0.87      0.75        45
#         Love       0.80      0.53      0.64        45
#      Sadness       0.57      0.78      0.66        45
#
#     accuracy                           0.63       225
#    macro avg       0.64      0.63      0.57       225
# weighted avg       0.64      0.63      0.57       225

# %%
accuracy = accuracy_score(y_true, y_pred)
precision_avg = precision_score(y_true, y_pred, average="macro", zero_division=0)
recall_avg = recall_score(y_true, y_pred, average="macro", zero_division=0)
f1_avg = f1_score(y_true, y_pred, average="macro", zero_division=0)

# %%
print(f"Precision avg : {precision_avg:.2f}")
print(f"Recall avg : {recall_avg:.2f}")
print(f"F1 avg : {f1_avg:.2f}")
print(f"Akurasi : {accuracy:.2f}")
# Out:
# Precision avg : 0.64
# Recall avg : 0.63
# F1 avg : 0.57
# Akurasi : 0.63

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# === Buat confusion matrix ===
cm = confusion_matrix(y_true, y_pred, labels=['Anger', 'Fear', 'Happy', 'Love', 'Sadness'])

# === Plot heatmap ===
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='YlGnBu',
            xticklabels=['Anger', 'Fear', 'Happy', 'Love', 'Sadness'],
            yticklabels=['Anger', 'Fear', 'Happy', 'Love', 'Sadness'])

plt.title("Confusion Matrix - LLM gpt-4.1-mini (5-Shot Emotion Classification)")
plt.xlabel("Predicted Emotion")
plt.ylabel("True Emotion")
plt.tight_layout()
plt.savefig("confusion_matrix_emotion_llm.png", dpi=300)
print("✅ Confusion matrix disimpan di 'confusion_matrix_emotion_llm.png'")
plt.show()
# Out:
# ✅ Confusion matrix disimpan di 'confusion_matrix_emotion_llm.png'

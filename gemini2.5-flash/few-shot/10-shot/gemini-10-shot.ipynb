# %%
import requests
import json
import pandas as pd
import time
from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    precision_score,
    recall_score,
    f1_score,
    accuracy_score
)
import matplotlib.pyplot as plt
import seaborn as sns
from pynvml import *
import psutil
import os
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_19952\2238081627.py:16: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   from pynvml import *

# %%
try:
    df = pd.read_csv("../../../test_llm.csv")
except FileNotFoundError:
    print("Error: File 'test_llm.csv' not found.")
    print("Pastikan file tersebut berada di direktori yang sama dengan script ini.")
    exit()

# %%
test_df = df.copy()
test_df['label_score'] = test_df['Emotion']

# %%
import os
import time
import json
import pandas as pd
from dotenv import load_dotenv, find_dotenv
from google import genai
from google.genai import types
from google.genai.errors import APIError
import requests # Masih diperlukan untuk psutil

# Muat Kunci API dari file .env
# Pastikan Anda memiliki file .env dengan baris: GEMINI_API_KEY="YOUR_API_KEY"
# Cari file .env dari direktori saat ini hingga ke atas
dotenv_path = find_dotenv(usecwd=True, raise_error_if_not_found=False)

if dotenv_path:
    load_dotenv(dotenv_path=dotenv_path)
else:
    print("⚠️ File .env tidak ditemukan di direktori proyek atau direktori induk.")
    # Script masih bisa berjalan jika API Key disetel sebagai Environment Variable sistem

# =================================================================
# === KONFIGURASI GEMINI API ===
# =================================================================
try:
    # Inisialisasi Klien Gemini
    client = genai.Client(api_key=os.getenv("GEMINI_API_KEY"))
    
    # Model yang diminta
    model_name = "gemini-2.5-flash"
    
except Exception as e:
    print(f"❌ Gagal menginisialisasi Gemini Client. Pastikan GEMINI_API_KEY disetel: {e}")
    # Keluar dari script jika kunci tidak ada
    client = None
    exit()

# =================================================================
# === GPU / RAM Monitor (Disederhanakan untuk RAM Lokal) ===
# VRAM monitoring dihapus karena model berjalan di cloud
# =================================================================
try:
    import psutil
    def get_ram_usage_gb():
        return psutil.virtual_memory().used / (1024 ** 3)
except ImportError:
    def get_ram_usage_gb():
        return 0.0 # Fallback jika psutil tidak terinstal

def get_vram_usage_gb():
    return 0.0 # Selalu 0.0 karena inferensi di cloud

# =================================================================
# === INISIALISASI VARIABEL ===
# =================================================================
emotion_labels = ["Anger", "Fear", "Happy", "Love", "Sadness"]
predictions = []
start_time = time.time()
PENDING_TIMEOUT = 5

# =================================================================
# === LOOP INFERENSI ===
# =================================================================

print(f"🚀 Memulai inferensi menggunakan model: {model_name}...")
print("-" * 50)

for i, row in test_df.iterrows():
    teks = row["Customer Review"]

    system_prompt = """
    Anda adalah asisten AI yang ahli dalam analisis emosi pada teks Bahasa Indonesia. 
    Tugas Anda adalah mengklasifikasikan teks pengguna ke dalam salah satu dari 
    5 kelas emosi berikut: Anger, Fear, Happy, Love, dan Sadness.

    Gunakan panduan karakteristik berikut:

    1. ANGER
    - Mengandung kata kasar atau makian.
    - Menunjukkan kemarahan, kekesalan, atau kebencian.
    - Keluhan atau ketidaksukaan terhadap produk/layanan/pengiriman.
    - Menggunakan huruf kapital berlebihan atau tanda baca marah (“!!!”, “???”).
    - Ekspresi jengkel, sebel, atau benci.

    2. FEAR
    - Kalimat peringatan atau rasa takut.
    - Kekhawatiran terhadap produk atau penjual.
    - Keraguan, ketidakpastian, atau menanyakan hal yang membuat cemas.
    - Ekspresi hati-hati, waspada, curiga, atau ragu terhadap keamanan.

    3. HAPPY
    - Mengandung pujian.
    - Kepuasan terhadap produk/penjual.
    - Ekspresi senang, gembira, bahagia, atau puas.
    - Bangga dan memberikan penilaian positif terhadap kualitas produk/penjual.

    4. LOVE
    - Ekspresi perasaan sayang, suka, atau rasa cinta.
    - Sangat puas terhadap produk.
    - Mengandung ungkapan hiperbola/“berlebihan” untuk menyanjung.
    - Mengandung pujian kuat atau kekaguman mendalam.
    - Ekspresi bangga atau sangat menyukai produk/penjual.

    5. SADNESS
    - Menyatakan kekecewaan terhadap produk.
    - Penyesalan, sedih, atau tidak puas.
    - Ekspresi kecewa, menyesal, atau merasa dirugikan.

    Keluaran Anda HARUS berupa JSON dengan format:
    {"emosi": "<Anger/Fear/Happy/Love/Sadness>"}
    """

    few_shot_examples = """
    Berikut adalah 10 contoh kasus klasifikasi emosi (10-SHOTS) beserta output JSON yang diharapkan. Model HARUS mengikuti format ini:

    --- Contoh 1 (Fear) ---
    Teks ulasan: "Barang tidak sesuai dengan yg di iklankan seperti nya bekas"
    Output: {"emosi": "Fear"}

    --- Contoh 2 (Fear) ---
    Teks ulasan: "Respon seller bagus tapi produknya tidak, suaranya kecil masih kalah dengan mic hp internal. Harga sangat tidak sesuai dengan kualitas"
    Output: {"emosi": "Fear"}
    
    --- Contoh 3 (Happy) ---
    Teks ulasan: "pengiriman cepat, packing rapi, kualitas mantap"
    Output: {"emosi": "Happy"}

    --- Contoh 4 (Happy) ---
    Teks ulasan: "Bagus, berkualitas, sesuai gbr. Makasih Seller, Tokped dan Kurir"
    Output: {"emosi": "Happy"}

    --- Contoh 5 (Anger) ---
    Teks ulasan: "Barang Rusak , Ga Guna Sama Sekali ... Parah"
    Output: {"emosi": "Anger"}

    --- Contoh 6 (Anger) ---
    Teks ulasan: "barang bosok! sekali Pake rusak.. mau claim dijawab berbelit ama adminnya"
    Output: {"emosi": "Anger"}

    --- Contoh 7 (Love) ---
    Teks ulasan: "Bagus banget keyboardnya. Packing sangat aman karena double kardus. Warna juga keren."
    Output: {"emosi": "Love"}

    --- Contoh 8 (Love) ---
    Teks ulasan: "Lucuu bangett.. Pengirimannya cepat, sellernya responsif banget.. Subuh2 di chat jg dijawab soalnya aku liat ini uda dr malam banget sih.. Kirain bakal baru dijawab agak siang.. Trnyata subuh uda dijawab?? informatif banget.. Ngsh tau klo dikasih oil agak berkabut.. Kirain bakal lbh berkabut dr ini.. Trnyata kabutnya cm kyk difoto.. Seneng deh.. Lampunya jg terang klo di tmpt gelap ?? makasihh yaa"
    Output: {"emosi": "Love"}

    --- Contoh 9 (Sadness) ---
    Teks ulasan: "Kecewa parah nggk berkah jualan gitu"
    Output: {"emosi": "Sadness"}

    --- Contoh 10 (Sadness) ---
    Teks ulasan: "Yg bikin kecewa pesen 6 items yg nyampe cuma satu. Masih saya tunggu kekurangan barangnya UNO STACKO KAYU, uno card 2pcs dan werewolf 2pcs. Kalau tidak tolong refund aja uangnya."
    Output: {"emosi": "Sadness"}

    Klasifikasikan teks ulasan baru di bawah berdasarkan konteks 10 contoh di atas.
    """

    # === USER PROMPT (Ditingkatkan dengan instruksi yang lebih tegas) ===
    user_prompt = f"""
    {few_shot_examples}
    
    Teks ulasan berikut: 
    "{teks}"

    Klasifikasikan teks tersebut ke dalam salah satu emosi berikut:
    {', '.join(emotion_labels)}.
    """
    
    messages = [
        types.Content(role="user", parts=[types.Part(text=user_prompt)]), # Gunakan constructor dengan keyword 'text'
    ]
    
    # Set System Instruction secara eksplisit untuk Gemini
    config = types.GenerateContentConfig(
        system_instruction=system_prompt,
        response_mime_type="application/json", # Instruksi output JSON
        response_schema={"type": "object", "properties": {"emosi": {"type": "string"}}}
    )

    t0 = time.time()

    try:
        # === REQUEST GEMINI API ===
        response = client.models.generate_content(
            model=model_name,
            contents=messages,
            config=config,
        )

        # --- Lacak Token ---
        if response.usage_metadata:
            input_tokens = response.usage_metadata.prompt_token_count
            output_tokens = response.usage_metadata.candidates_token_count
        # -------------------
        
        assistant_response_string = response.text.strip()
        
        if not assistant_response_string:
            print(f"[{i}] ⚠️ Respons kosong dari model untuk: {teks[:60]}...")
            continue
            
        try:
            # Karena kita meminta JSON, kita bisa langsung memuatnya.
            hasil = json.loads(assistant_response_string)
        except json.JSONDecodeError:
            print(f"[{i}] ⚠️ Gagal parse JSON dari respons teks mentah: {assistant_response_string}")
            continue

        emosi_pred = hasil.get("emosi", "").capitalize().strip()

        if emosi_pred not in emotion_labels:
            print(f"[{i}] 🛑 Emosi tidak valid ({emosi_pred}). Fallback ke Neutral.")
            emosi_pred = "Neutral" 

        latency = time.time() - t0
        ram_usage = get_ram_usage_gb()
        vram_usage = get_vram_usage_gb()

        predictions.append({
            "text": teks,
            "actual": row["Emotion"],
            "predicted": emosi_pred,
            "latency_sec": latency,
            "ram_gb": ram_usage,
            "vram_gb": vram_usage,
            "prompt_tokens": input_tokens,
            "completion_tokens": output_tokens
        })

        print(f"[{i}] {teks[:60]}... → Pred: **{emosi_pred}** "
              f"({latency:.2f}s) | Token: In={input_tokens}, Out={output_tokens} | RAM: {ram_usage:.2f} GB")
        
        # === TIMEOUT PENDING 10 DETIK ===
        print(f"[{i}] 💤 Menunggu {PENDING_TIMEOUT} detik...")
        time.sleep(PENDING_TIMEOUT)
        # ===============================
        
        
    except APIError as e:
        print(f"[{i}] ❌ Kesalahan API Gemini: {e}")
        # Lanjutkan ke iterasi berikutnya atau hentikan jika error fatal
        continue 
    except Exception as e:
        print(f"[{i}] ⚠️ Error tak terduga memproses teks: {teks[:60]} | Detail: {e}")
        continue

# =================================================================
# === RINGKASAN STATISTIK (Diperbarui untuk Token) ===
# =================================================================
end_time = time.time()
total_time = end_time - start_time

if predictions:
    latencies = [p["latency_sec"] for p in predictions]
    # Abaikan latency pertama (warm-up)
    latencies_no_first = latencies[1:] if len(latencies) > 1 else latencies
    
    avg_latency = sum(latencies_no_first) / len(latencies_no_first) if latencies_no_first else 0
    total_time_no_first = sum(latencies_no_first)
    throughput = (len(latencies_no_first) / total_time_no_first) * 60 if total_time_no_first > 0 else 0

    avg_ram = sum(p["ram_gb"] for p in predictions) / len(predictions)
    avg_vram = sum(p["vram_gb"] for p in predictions) / len(predictions)
    
    avg_prompt_tokens = sum(p["prompt_tokens"] for p in predictions) / len(predictions)
    avg_completion_tokens = sum(p["completion_tokens"] for p in predictions) / len(predictions)


    print("\n" + "=" * 50)
    print("=== 📊 Ringkasan Evaluasi ===")
    print("=" * 50)
    print(f"Total sampel diproses: {len(predictions)} dari {len(test_df)}")
    print(f"Total waktu uji coba : {total_time:.2f} detik")
    print(f"Rata-rata latency: **{avg_latency:.2f} detik/sampel** (tanpa warm-up)")
    print(f"Throughput: **{throughput:.2f} sampel/menit** (tanpa warm-up)")
    print("-" * 50)
    print(f"Rata-rata Prompt Tokens: {avg_prompt_tokens:.0f}")
    print(f"Rata-rata Completion Tokens: {avg_completion_tokens:.0f}")
    print("-" * 50)
    print(f"Rata-rata RAM: {avg_ram:.2f} GB")
    print(f"Rata-rata VRAM: {avg_vram:.2f} GB")
    print("=" * 50)

    # === Simpan ke CSV ===
    results_df = pd.DataFrame(predictions)
    results_df.to_csv("results_metrics_emotion.csv", index=False)
    print("\n✅ Hasil disimpan ke: **results_metrics_emotion.csv**")
else:
    print("\n❌ Tidak ada prediksi yang berhasil disimpan. Cek koneksi Anda ke API dan Kunci API.")
# Out:
# 🚀 Memulai inferensi menggunakan model: gemini-2.5-flash...
# --------------------------------------------------
# [0] buahnya bagus... kurirnya ok sellernya juga ok... → Pred: **Happy** (2.35s) | Token: In=1167, Out=7 | RAM: 12.98 GB
# [0] 💤 Menunggu 5 detik...
# [1] Ada sedikit cacat, selainnya oke... → Pred: **Sadness** (4.27s) | Token: In=1163, Out=8 | RAM: 12.93 GB
# [1] 💤 Menunggu 5 detik...
# [2] Jadi semangat mancing.... → Pred: **Happy** (2.85s) | Token: In=1159, Out=7 | RAM: 12.94 GB
# [2] 💤 Menunggu 5 detik...
# [3] Cepat tiba n kemasan bagus. barangnya juga bagus... → Pred: **Happy** (2.48s) | Token: In=1167, Out=7 | RAM: 13.14 GB
# [3] 💤 Menunggu 5 detik...
# [4] Produk sesuai deskripsi??. Variasi produk beragam. Berfungsi... → Pred: **Happy** (5.55s) | Token: In=1171, Out=7 | RAM: 13.27 GB
# [4] 💤 Menunggu 5 detik...
# [5] pelayanan memuaskan dan barang sesuai ??... → Pred: **Happy** (4.15s) | Token: In=1164, Out=7 | RAM: 13.14 GB
# [5] 💤 Menunggu 5 detik...
# [6] Barang bagus dan cepat sekali sampainya ke cianjur, hanya 2 ... → Pred: **Happy** (4.55s) | Token: In=1175, Out=7 | RAM: 13.11 GB
# [6] 💤 Menunggu 5 detik...
# [7] Bagus mantab jernih... → Pred: **Happy** (3.31s) | Token: In=1162, Out=7 | RAM: 13.10 GB
# [7] 💤 Menunggu 5 detik...
# [8] trmksh barang sesuai pesanan, fungsi normal... tingkatkan te... → Pred: **Happy** (2.85s) | Token: In=1170, Out=7 | RAM: 13.15 GB
# [8] 💤 Menunggu 5 detik...
# [9] Green screen sudah nyampe, bahan cukup tebal, mirip ntah sam... → Pred: **Happy** (3.46s) | Token: In=1187, Out=7 | RAM: 13.15 GB
# [9] 💤 Menunggu 5 detik...
# [10] lumayan lah, buat pemanasan... → Pred: **Happy** (3.15s) | Token: In=1163, Out=7 | RAM: 13.18 GB
# [10] 💤 Menunggu 5 detik...
# [11] paking rapih, kondisi barang datang mantap. kualitas sesuai ... → Pred: **Happy** (2.83s) | Token: In=1173, Out=7 | RAM: 13.24 GB
# [11] 💤 Menunggu 5 detik...
# [12] produk asli original. suplemen bagus tanpa efek samping, sem... → Pred: **Happy** (3.60s) | Token: In=1179, Out=7 | RAM: 13.16 GB
# [12] 💤 Menunggu 5 detik...
# [13] barang bagus dan layanan bagus... → Pred: **Happy** (2.94s) | Token: In=1160, Out=7 | RAM: 6.76 GB
# [13] 💤 Menunggu 5 detik...
# [14] ❌ Kesalahan API Gemini: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}
# [15] Cepet nyampe, seller oke... → Pred: **Happy** (2.57s) | Token: In=1162, Out=7 | RAM: 9.38 GB
# [15] 💤 Menunggu 5 detik...
# [16] barang sdh nyampe dgn baik. senang banget terima paketnya. s... → Pred: **Happy** (3.47s) | Token: In=1189, Out=7 | RAM: 13.27 GB
# [16] 💤 Menunggu 5 detik...
# [17] Kainnya gk tipis, standar tebal batik biasa, adem , lembut, ... → Pred: **Happy** (3.44s) | Token: In=1181, Out=7 | RAM: 13.28 GB
# [17] 💤 Menunggu 5 detik...
# [18] Barusan saya tes untuk ambil sampah di sungai dekat rumah, u... → Pred: **Sadness** (7.63s) | Token: In=1208, Out=8 | RAM: 13.30 GB
# [18] 💤 Menunggu 5 detik...
# [19] alhamdulillah, produk ini sangat membantu. yang biasanya mem... → Pred: **Love** (4.28s) | Token: In=1380, Out=7 | RAM: 13.32 GB
# [19] 💤 Menunggu 5 detik...
# [20] sesuai dengan pesanan, bahan halus, kayaknya adem...... → Pred: **Happy** (2.96s) | Token: In=1169, Out=7 | RAM: 13.36 GB
# [20] 💤 Menunggu 5 detik...
# [21] sudah terima packingnya rapi, bahannya lembut, enak dipake, ... → Pred: **Happy** (3.79s) | Token: In=1185, Out=7 | RAM: 13.41 GB
# [21] 💤 Menunggu 5 detik...
# [22] Barang Sesuai Deskripsi. Produk Original. Packaging Bagus.... → Pred: **Happy** (3.59s) | Token: In=1169, Out=7 | RAM: 13.37 GB
# [22] 💤 Menunggu 5 detik...
# [23] mantap, bagus dan teba... → Pred: **Happy** (3.56s) | Token: In=1162, Out=7 | RAM: 13.39 GB
# [23] 💤 Menunggu 5 detik...
# [24] Sesuai deskripsi dan pesanan. Terimakasih... → Pred: **Happy** (2.42s) | Token: In=1168, Out=7 | RAM: 13.81 GB
# [24] 💤 Menunggu 5 detik...
# [25] Produk Sesuai. Material Produk Bagus. Cocok untuk di jadikan... → Pred: **Happy** (3.60s) | Token: In=1192, Out=7 | RAM: 13.89 GB
# [25] 💤 Menunggu 5 detik...
# [26] wae keren. alatnya berasa jadi pengrajin rokok. matap seler ... → Pred: **Love** (4.26s) | Token: In=1185, Out=7 | RAM: 13.98 GB
# [26] 💤 Menunggu 5 detik...
# [27] Bagus dan ini order saya yang kedua.... → Pred: **Happy** (3.24s) | Token: In=1163, Out=7 | RAM: 13.97 GB
# [27] 💤 Menunggu 5 detik...
# [28] Teksturnya creamy. Gampang dipakai. Packaging aman ??.... → Pred: **Happy** (5.76s) | Token: In=1167, Out=7 | RAM: 13.99 GB
# [28] 💤 Menunggu 5 detik...
# [29] masker bagus,sesuai harga`... → Pred: **Happy** (3.13s) | Token: In=1164, Out=7 | RAM: 13.67 GB
# [29] 💤 Menunggu 5 detik...
# [30] bagus banget bahan nya juga adem ini bakal jadi langganan sa... → Pred: **Love** (3.90s) | Token: In=1176, Out=7 | RAM: 13.38 GB
# [30] 💤 Menunggu 5 detik...
# [31] respon baik mutu lumayan hrg terjangkau... → Pred: **Happy** (3.26s) | Token: In=1165, Out=7 | RAM: 13.51 GB
# [31] 💤 Menunggu 5 detik...
# [32] Kualitas Produk Bagus. Produk Sesuai... → Pred: **Happy** (2.53s) | Token: In=1165, Out=7 | RAM: 13.52 GB
# [32] 💤 Menunggu 5 detik...
# [33] Bahan bagus, kain bisa melebar dan elastis... → Pred: **Happy** (3.16s) | Token: In=1166, Out=7 | RAM: 13.62 GB
# [33] 💤 Menunggu 5 detik...
# [34] Cepat, rapih dan aman. Saya mau beli lagi nanti ya... → Pred: **Happy** (3.07s) | Token: In=1170, Out=7 | RAM: 13.59 GB
# [34] 💤 Menunggu 5 detik...
# [35] Cepat dan packing amanah bgt.kualitas susu sdh terjamin enak... → Pred: **Love** (5.50s) | Token: In=1176, Out=7 | RAM: 13.55 GB
# [35] 💤 Menunggu 5 detik...
# [36] barang telah sampai dengan packaging yg bagus... → Pred: **Happy** (2.83s) | Token: In=1162, Out=7 | RAM: 13.44 GB
# [36] 💤 Menunggu 5 detik...
# [37] ukurannya ada yg besar ada yg kecil tapi lumayan dengan harg... → Pred: **Happy** (4.39s) | Token: In=1174, Out=7 | RAM: 13.41 GB
# [37] 💤 Menunggu 5 detik...
# [38] bagus, bisa nempel di kayu... → Pred: **Happy** (2.74s) | Token: In=1163, Out=7 | RAM: 13.41 GB
# [38] 💤 Menunggu 5 detik...
# [39] alhamdulillah barang sampai di tgl 6/11. Isi dusnya : instru... → Pred: **Happy** (3.31s) | Token: In=1208, Out=7 | RAM: 13.40 GB
# [39] 💤 Menunggu 5 detik...
# [40] Jahitannya rapi. Warnanya cantik ??. Bahannya lembut. Ukuran... → Pred: **Love** (4.04s) | Token: In=1187, Out=7 | RAM: 13.40 GB
# [40] 💤 Menunggu 5 detik...
# [41] Mantap keren. Cuma harus colok listrik kalau mau pakai fitur... → Pred: **Happy** (4.34s) | Token: In=1192, Out=7 | RAM: 13.41 GB
# [41] 💤 Menunggu 5 detik...
# [42] Pertama x custom dan hasil ny sesuai request... → Pred: **Happy** (2.58s) | Token: In=1164, Out=7 | RAM: 13.42 GB
# [42] 💤 Menunggu 5 detik...
# [43] mantap paten joss... → Pred: **Love** (5.08s) | Token: In=1161, Out=7 | RAM: 13.42 GB
# [43] 💤 Menunggu 5 detik...
# [44] packing rapih aman makasih... → Pred: **Happy** (2.77s) | Token: In=1162, Out=7 | RAM: 13.43 GB
# [44] 💤 Menunggu 5 detik...
# [45] warnanya ga sesuai photo di deskripsi warna sepatu di deskri... → Pred: **Sadness** (3.75s) | Token: In=1178, Out=8 | RAM: 13.63 GB
# [45] 💤 Menunggu 5 detik...
# [46] Ada 1 shade yg salah kirim... → Pred: **Sadness** (3.36s) | Token: In=1163, Out=8 | RAM: 13.65 GB
# [46] 💤 Menunggu 5 detik...
# [47] barang biasa aja ...bahan kurang bgitu bagus... → Pred: **Sadness** (4.36s) | Token: In=1164, Out=8 | RAM: 13.54 GB
# [47] 💤 Menunggu 5 detik...
# [48] Jahitannya berantakan banget. gak kenceng aku benyeng dikit ... → Pred: **Sadness** (4.18s) | Token: In=1183, Out=8 | RAM: 13.53 GB
# [48] 💤 Menunggu 5 detik...
# [49] bahan ny sih bagus, cm sayang pesen nya 2 datang ny 1. d cha... → Pred: **Anger** (5.62s) | Token: In=1201, Out=8 | RAM: 13.51 GB
# [49] 💤 Menunggu 5 detik...
# [50] Packingnya cm kresek krg aman, jd pas dateng peot pdhl buat ... → Pred: **Sadness** (6.13s) | Token: In=1179, Out=8 | RAM: 13.52 GB
# [50] 💤 Menunggu 5 detik...
# [51] Kecewa dengan waktu pengiriman. Order jam 11.52 sengaja pili... → Pred: **Sadness** (5.09s) | Token: In=1239, Out=8 | RAM: 13.50 GB
# [51] 💤 Menunggu 5 detik...
# [52] Dlm ordernya sdh sy tambah 'bubble wrap' (+ rp 10.000), tp d... → Pred: **Anger** (6.66s) | Token: In=1210, Out=8 | RAM: 13.50 GB
# [52] 💤 Menunggu 5 detik...
# [53] bungkusan barang robek, ada bagian kertas yg sudah kuning me... → Pred: **Sadness** (3.35s) | Token: In=1180, Out=8 | RAM: 13.51 GB
# [53] 💤 Menunggu 5 detik...
# [54] balonnya kecil sekali ga sesuai gambar..ga bagus kualitas..k... → Pred: **Sadness** (4.09s) | Token: In=1177, Out=8 | RAM: 13.51 GB
# [54] 💤 Menunggu 5 detik...
# [55] Batre tidak sesuai ukuran dan tidak ada nano receiver.... → Pred: **Sadness** (4.56s) | Token: In=1165, Out=8 | RAM: 13.49 GB
# [55] 💤 Menunggu 5 detik...
# [56] overpriced.. analisanya kurang dalam. kualitas hard cover ku... → Pred: **Anger** (5.25s) | Token: In=1178, Out=8 | RAM: 13.61 GB
# [56] 💤 Menunggu 5 detik...
# [57] boros batre... → Pred: **Sadness** (15.61s) | Token: In=1159, Out=8 | RAM: 13.56 GB
# [57] 💤 Menunggu 5 detik...
# [58] yg micro ini sering rusak coba di tingkatkn lg kualitasnya... → Pred: **Sadness** (5.70s) | Token: In=1167, Out=8 | RAM: 13.51 GB
# [58] 💤 Menunggu 5 detik...
# [59] sambungannya tidak rapih..... → Pred: **Sadness** (2.23s) | Token: In=1161, Out=8 | RAM: 13.57 GB
# [59] 💤 Menunggu 5 detik...
# [60] Barang sampai dengan selamat, mic berfungsi tapi emang kuali... → Pred: **Sadness** (4.96s) | Token: In=1177, Out=8 | RAM: 13.59 GB
# [60] 💤 Menunggu 5 detik...
# [61] kurang bagus... → Pred: **Sadness** (2.11s) | Token: In=1158, Out=8 | RAM: 13.59 GB
# [61] 💤 Menunggu 5 detik...
# [62] model lumayan kren tapi kecewa di batre senternya hnya berta... → Pred: **Sadness** (3.56s) | Token: In=1177, Out=8 | RAM: 13.44 GB
# [62] 💤 Menunggu 5 detik...
# [63] tidak berfugsi... → Pred: **Sadness** (4.28s) | Token: In=1159, Out=8 | RAM: 13.03 GB
# [63] 💤 Menunggu 5 detik...
# [64] Baru seminggu pemakaian sudah tidak bisa nyala sebelah... → Pred: **Sadness** (5.92s) | Token: In=1168, Out=8 | RAM: 13.04 GB
# [64] 💤 Menunggu 5 detik...
# [65] Barang gak berfungsi, kalo mau dikirim cek dulu bos senter g... → Pred: **Anger** (7.07s) | Token: In=1189, Out=8 | RAM: 13.18 GB
# [65] 💤 Menunggu 5 detik...
# [66] barang dikrm beda dgn yg pesan... → Pred: **Sadness** (3.24s) | Token: In=1163, Out=8 | RAM: 13.22 GB
# [66] 💤 Menunggu 5 detik...
# [67] Beli 3 barang, hanya dikirim 2. Saat komplain dijanjikan bar... → Pred: **Sadness** (5.77s) | Token: In=1213, Out=8 | RAM: 13.35 GB
# [67] 💤 Menunggu 5 detik...
# [68] Barang yang sampai cacat, tidak ngisi baterai stick nya... → Pred: **Sadness** (5.25s) | Token: In=1169, Out=8 | RAM: 13.41 GB
# [68] 💤 Menunggu 5 detik...
# [69] Sangat kecewa dengan barang yg di terima segel Samsung sudah... → Pred: **Fear** (8.69s) | Token: In=1290, Out=7 | RAM: 13.39 GB
# [69] 💤 Menunggu 5 detik...
# [70] Paking tidak rapih jebol... → Pred: **Anger** (8.05s) | Token: In=1163, Out=8 | RAM: 13.30 GB
# [70] 💤 Menunggu 5 detik...
# [71] Ada kekecewaan ketika lihat brg datang.....Aq pikir barang b... → Pred: **Sadness** (3.83s) | Token: In=1211, Out=8 | RAM: 13.30 GB
# [71] 💤 Menunggu 5 detik...
# [72] kecewa dengan pelayanan toko ini, Dan nyesal denga toko ini,... → Pred: **Sadness** (7.46s) | Token: In=1207, Out=8 | RAM: 13.30 GB
# [72] 💤 Menunggu 5 detik...
# [73] barang dibungkus pakai bubblewarp, trs pecah gatau dari jasa... → Pred: **Sadness** (3.03s) | Token: In=1194, Out=8 | RAM: 13.31 GB
# [73] 💤 Menunggu 5 detik...
# [74] ujung buku rusak.. padahal sudah mahal beli buku import... → Pred: **Sadness** (4.32s) | Token: In=1167, Out=8 | RAM: 13.30 GB
# [74] 💤 Menunggu 5 detik...
# [75] baru pakai beberapa kali, sponnya terpisah jadi 3, lemnya ti... → Pred: **Sadness** (6.03s) | Token: In=1173, Out=8 | RAM: 13.31 GB
# [75] 💤 Menunggu 5 detik...
# [76] ukurannya tidak sesuai..pesan 5x7 dikirim 4x6... → Pred: **Sadness** (5.21s) | Token: In=1172, Out=8 | RAM: 13.42 GB
# [76] 💤 Menunggu 5 detik...
# [77] Suaranya gk bs bersih. Ada noise. Hasilnya lebih bagus ngere... → Pred: **Sadness** (7.25s) | Token: In=1179, Out=8 | RAM: 13.37 GB
# [77] 💤 Menunggu 5 detik...
# [78] Padahal udah tanya sebelumnya sama penjualnya ada ga balon w... → Pred: **Sadness** (4.30s) | Token: In=1221, Out=8 | RAM: 13.36 GB
# [78] 💤 Menunggu 5 detik...
# [79] belom 1 bulan udah gak nyala, baterai udah diganti tetap saj... → Pred: **Anger** (6.32s) | Token: In=1189, Out=8 | RAM: 13.32 GB
# [79] 💤 Menunggu 5 detik...
# [80] Packing kurang rapih, pinggir buku menjadi rusak... → Pred: **Sadness** (5.78s) | Token: In=1166, Out=8 | RAM: 13.33 GB
# [80] 💤 Menunggu 5 detik...
# [81] Bahan sangat mudah bengkok pdhl hanya sepatu & sambungan mud... → Pred: **Sadness** (3.41s) | Token: In=1170, Out=8 | RAM: 13.33 GB
# [81] 💤 Menunggu 5 detik...
# [82] infra red nya jelek suka mental ke mana2... → Pred: **Sadness** (5.31s) | Token: In=1165, Out=8 | RAM: 13.28 GB
# [82] 💤 Menunggu 5 detik...
# [83] lambat... → Pred: **Anger** (8.25s) | Token: In=1157, Out=8 | RAM: 13.31 GB
# [83] 💤 Menunggu 5 detik...
# [84] tipis bgt... → Pred: **Sadness** (2.21s) | Token: In=1159, Out=8 | RAM: 13.31 GB
# [84] 💤 Menunggu 5 detik...
# [85] kecewa sekali ada 10 lembar warnanya beda memang sekilas ben... → Pred: **Sadness** (3.25s) | Token: In=1201, Out=8 | RAM: 13.40 GB
# [85] 💤 Menunggu 5 detik...
# [86] kacamata sangat rentan. dipakai sekali patah. karena bagian ... → Pred: **Sadness** (4.59s) | Token: In=1186, Out=8 | RAM: 13.28 GB
# [86] 💤 Menunggu 5 detik...
# [87] Packing tdk ada, sudah tau pengiriman jauh tp tdk dilapisi p... → Pred: **Sadness** (5.20s) | Token: In=1180, Out=8 | RAM: 13.29 GB
# [87] 💤 Menunggu 5 detik...
# [88] kecewa bagt. barang yg di kirim tidak sesuai. masih kurang 3... → Pred: **Sadness** (4.10s) | Token: In=1196, Out=8 | RAM: 13.29 GB
# [88] 💤 Menunggu 5 detik...
# [89] saya sangat kecewa belanja di toko ini. respon penjual cuek.... → Pred: **Sadness** (3.42s) | Token: In=1202, Out=8 | RAM: 13.30 GB
# [89] 💤 Menunggu 5 detik...
# [90] wah sy pake sameday..masa dtgnya besoknya. smtra sy byr jam ... → Pred: **Sadness** (6.88s) | Token: In=1217, Out=8 | RAM: 13.33 GB
# [90] 💤 Menunggu 5 detik...
# [91] mohon maaf dikasih rating segini, karena barang yg dikirim t... → Pred: **Sadness** (3.42s) | Token: In=1195, Out=8 | RAM: 13.33 GB
# [91] 💤 Menunggu 5 detik...
# [92] pembelian ke 2 beda 10 hari aja, kenapa pelet maxi nya beda ... → Pred: **Fear** (6.07s) | Token: In=1192, Out=7 | RAM: 13.16 GB
# [92] 💤 Menunggu 5 detik...
# [93] Barangnya ga ada... → Pred: **Sadness** (2.81s) | Token: In=1159, Out=8 | RAM: 13.19 GB
# [93] 💤 Menunggu 5 detik...
# [94] Bahan plastiknya tdk stretch, kaku dan tidak bagus aluas tdk... → Pred: **Sadness** (6.41s) | Token: In=1183, Out=8 | RAM: 13.16 GB
# [94] 💤 Menunggu 5 detik...
# [95] bad admin. Opportunity lost gara2 mau tambah pesanan tp diab... → Pred: **Anger** (6.04s) | Token: In=1180, Out=8 | RAM: 13.17 GB
# [95] 💤 Menunggu 5 detik...
# [96] PO udah sebulan gak sampai cm d kirim voucher dan di janjika... → Pred: **Anger** (5.08s) | Token: In=1201, Out=8 | RAM: 13.16 GB
# [96] 💤 Menunggu 5 detik...
# [97] Pengirimannya sih cepat, tapi barangnya bruntusan gitu. Tema... → Pred: **Sadness** (3.48s) | Token: In=1220, Out=8 | RAM: 13.14 GB
# [97] 💤 Menunggu 5 detik...
# [98] kemasan hancurrr pecah berantakan... ga jadi kepakai... ssmo... → Pred: **Anger** (8.99s) | Token: In=1183, Out=8 | RAM: 13.21 GB
# [98] 💤 Menunggu 5 detik...
# [99] pengiriman pertama sudah expired. barang diganti baru tp exp... → Pred: **Sadness** (4.22s) | Token: In=1191, Out=8 | RAM: 13.19 GB
# [99] 💤 Menunggu 5 detik...
# [100] tidak sesuai... → Pred: **Sadness** (6.63s) | Token: In=1157, Out=8 | RAM: 13.13 GB
# [100] 💤 Menunggu 5 detik...
# [101] Miniboxnya sih ok lampu led berfungsi dan menyala semua , ta... → Pred: **Anger** (4.19s) | Token: In=1251, Out=8 | RAM: 13.15 GB
# [101] 💤 Menunggu 5 detik...
# [102] barang datang tidak lengkap. yidak akan pernah belanja lagi ... → Pred: **Sadness** (5.59s) | Token: In=1172, Out=8 | RAM: 13.15 GB
# [102] 💤 Menunggu 5 detik...
# [103] Hari ini baru terpasang. Ternyata ada satu palang yg ukuran ... → Pred: **Sadness** (4.29s) | Token: In=1213, Out=8 | RAM: 13.14 GB
# [103] 💤 Menunggu 5 detik...
# [104] Admin toko ini tdk punya sopan santun, bukannya cari solusi ... → Pred: **Anger** (4.57s) | Token: In=1194, Out=8 | RAM: 13.16 GB
# [104] 💤 Menunggu 5 detik...
# [105] gk ada plat besinya...cm ada label merk bahan... → Pred: **Sadness** (6.11s) | Token: In=1166, Out=8 | RAM: 13.16 GB
# [105] 💤 Menunggu 5 detik...
# [106] Iklannya Seragam PGRI Kemeja Hem Katun Pria. Tp ternyata bah... → Pred: **Sadness** (3.50s) | Token: In=1197, Out=8 | RAM: 13.16 GB
# [106] 💤 Menunggu 5 detik...
# [107] packaging gk aman bgt, bubble wrap tipis alhasil kemasan bar... → Pred: **Anger** (6.41s) | Token: In=1195, Out=8 | RAM: 13.14 GB
# [107] 💤 Menunggu 5 detik...
# [108] barangnya gak sesuai gambar, biasa aja, pantes hrg murah... → Pred: **Sadness** (6.75s) | Token: In=1169, Out=8 | RAM: 13.16 GB
# [108] 💤 Menunggu 5 detik...
# [109] kartu tidak terdeteksi jadi jam gk cocok, sudah coba2 cari d... → Pred: **Sadness** (4.18s) | Token: In=1186, Out=8 | RAM: 13.15 GB
# [109] 💤 Menunggu 5 detik...
# [110] Produk nya bocor karena packing nya krg bgs. Dr dus luar nya... → Pred: **Sadness** (6.28s) | Token: In=1203, Out=8 | RAM: 13.14 GB
# [110] 💤 Menunggu 5 detik...
# [111] Barang yang dikirimkan tidak sesuai dengan orderan saya, dit... → Pred: **Anger** (4.64s) | Token: In=1242, Out=8 | RAM: 13.13 GB
# [111] 💤 Menunggu 5 detik...
# [112] Koneksi perangkat susah, kalaupun konek seringkali putus, bu... → Pred: **Fear** (8.02s) | Token: In=1192, Out=7 | RAM: 13.15 GB
# [112] 💤 Menunggu 5 detik...
# [113] tidak recommend banget pelayanan ngk bagus dan tidak sesuai ... → Pred: **Sadness** (7.09s) | Token: In=1179, Out=8 | RAM: 13.15 GB
# [113] 💤 Menunggu 5 detik...
# [114] barang tidak sampai. tdk ada solusi... → Pred: **Sadness** (4.92s) | Token: In=1163, Out=8 | RAM: 13.16 GB
# [114] 💤 Menunggu 5 detik...
# [115] beli 5 pd gosong semua.??baru apa bekas nih? biasanya beli g... → Pred: **Fear** (7.16s) | Token: In=1182, Out=7 | RAM: 13.16 GB
# [115] 💤 Menunggu 5 detik...
# [116] bukan soal uangnya ,tapi soal ke amanahannya. kirim barang a... → Pred: **Anger** (6.08s) | Token: In=1236, Out=8 | RAM: 13.16 GB
# [116] 💤 Menunggu 5 detik...
# [117] baunya pasaran, prtama kali pakai semua orang sekitar gue sa... → Pred: **Sadness** (6.32s) | Token: In=1186, Out=8 | RAM: 13.22 GB
# [117] 💤 Menunggu 5 detik...
# [118] Pesanan tidak dikirim, tidak ada komunikasi apapun, tidak ad... → Pred: **Sadness** (5.17s) | Token: In=1175, Out=8 | RAM: 13.19 GB
# [118] 💤 Menunggu 5 detik...
# [119] sangat kecewa belanja disini, response sangat lambat,order i... → Pred: **Anger** (6.17s) | Token: In=1197, Out=8 | RAM: 13.19 GB
# [119] 💤 Menunggu 5 detik...
# [120] mesin kasar, pelayanan kurang... → Pred: **Anger** (3.66s) | Token: In=1161, Out=8 | RAM: 13.14 GB
# [120] 💤 Menunggu 5 detik...
# [121] packingnya kurang memuaskan... → Pred: **Sadness** (2.94s) | Token: In=1161, Out=8 | RAM: 13.18 GB
# [121] 💤 Menunggu 5 detik...
# [122] dipakai untuk mindahin tabung gas 12 kg sangat seret, susah ... → Pred: **Sadness** (5.75s) | Token: In=1212, Out=8 | RAM: 13.18 GB
# [122] 💤 Menunggu 5 detik...
# [123] Sy order 5pcs dikirim cuma 4, Krn weekend senin sy Baru Cek ... → Pred: **Anger** (4.83s) | Token: In=1196, Out=8 | RAM: 13.18 GB
# [123] 💤 Menunggu 5 detik...
# [124] ⚠️ Error tak terduga memproses teks: untuk jepit ke mejanya loss. ga bisa ngunci. sudah di coba d | Detail: Server disconnected without sending a response.
# [125] Parah ini toko ga ada tanggung jawab nya... → Pred: **Anger** (4.61s) | Token: In=1164, Out=8 | RAM: 13.15 GB
# [125] 💤 Menunggu 5 detik...
# [126] Waktu sampai nya lakban Tokopedia di saya sangat lama,ketika... → Pred: **Anger** (5.01s) | Token: In=1196, Out=8 | RAM: 13.17 GB
# [126] 💤 Menunggu 5 detik...
# [127] Ternyata tidak sesuai. Tidak dpat dipakai... → Pred: **Sadness** (4.96s) | Token: In=1165, Out=8 | RAM: 13.14 GB
# [127] 💤 Menunggu 5 detik...
# [128] beli 2 dipakai dua hari udah hangus. kapok beli disini. 2 ca... → Pred: **Sadness** (6.63s) | Token: In=1179, Out=8 | RAM: 13.19 GB
# [128] 💤 Menunggu 5 detik...
# [129] Sudah kuduga kalau beli banyak, pasti ada beberapa yang bara... → Pred: **Anger** (8.33s) | Token: In=1241, Out=8 | RAM: 13.19 GB
# [129] 💤 Menunggu 5 detik...
# [130] Barang baru diterima dicoba ternyata sudah rusak, masak nasi... → Pred: **Sadness** (8.26s) | Token: In=1231, Out=8 | RAM: 13.18 GB
# [130] 💤 Menunggu 5 detik...
# [131] bukan dendeng daging sapi asli, semacam campuran... → Pred: **Sadness** (10.93s) | Token: In=1166, Out=8 | RAM: 13.18 GB
# [131] 💤 Menunggu 5 detik...
# [132] beli 10pcs hampir rusak semua bentuknya, dan toko terus berd... → Pred: **Anger** (7.68s) | Token: In=1182, Out=8 | RAM: 13.18 GB
# [132] 💤 Menunggu 5 detik...
# [133] Barangnya tidak seperti barang baru dan tanpa kemasan pabrik... → Pred: **Fear** (7.82s) | Token: In=1167, Out=7 | RAM: 13.22 GB
# [133] 💤 Menunggu 5 detik...
# [134] Gak sesuai gambar disitu gulanya yg hijau kenapa dikirimnya ... → Pred: **Sadness** (3.95s) | Token: In=1199, Out=8 | RAM: 13.22 GB
# [134] 💤 Menunggu 5 detik...
# [135] Fastresp banget, ramah juga, pengirimannya gercep banget, lv... → Pred: **Fear** (7.37s) | Token: In=1197, Out=7 | RAM: 13.23 GB
# [135] 💤 Menunggu 5 detik...
# [136] wow wow sangaat praktis euy, tapi emang harganya mayaan sihh... → Pred: **Love** (7.37s) | Token: In=1186, Out=7 | RAM: 13.20 GB
# [136] 💤 Menunggu 5 detik...
# [137] puas banget ????????????????... → Pred: **Love** (6.52s) | Token: In=1162, Out=7 | RAM: 13.20 GB
# [137] 💤 Menunggu 5 detik...
# [138] mantaaaaaaaaapppppp pelayanan cepat pengirimannya... top mar... → Pred: **Love** (3.59s) | Token: In=1186, Out=7 | RAM: 13.27 GB
# [138] 💤 Menunggu 5 detik...
# [139] Mienya enak Favorit keluarga. Sudah langganan beli mie sedap... → Pred: **Love** (6.18s) | Token: In=1187, Out=7 | RAM: 13.20 GB
# [139] 💤 Menunggu 5 detik...
# [140] barang bagus..Bahannya adem. Modelnya cantik ??.... → Pred: **Love** (4.75s) | Token: In=1167, Out=7 | RAM: 13.20 GB
# [140] 💤 Menunggu 5 detik...
# [141] reoderrrrr... → Pred: **Love** (3.14s) | Token: In=1159, Out=7 | RAM: 13.20 GB
# [141] 💤 Menunggu 5 detik...
# [142] Seller ramah dan fast response. Packaging rapih dan kualitas... → Pred: **Love** (6.28s) | Token: In=1175, Out=7 | RAM: 13.18 GB
# [142] 💤 Menunggu 5 detik...
# [143] Produk sesuai, pengiriman cepat, packing aman, recommended s... → Pred: **Happy** (7.92s) | Token: In=1169, Out=7 | RAM: 13.21 GB
# [143] 💤 Menunggu 5 detik...
# [144] Instalasi Mudah. pengiriman cpt. respon cpt, trims seller sm... → Pred: **Happy** (3.09s) | Token: In=1184, Out=7 | RAM: 13.31 GB
# [144] 💤 Menunggu 5 detik...
# [145] Sudah order yg kedua disini, packingnya rapi, untuk lilin sa... → Pred: **Love** (8.52s) | Token: In=1242, Out=7 | RAM: 13.12 GB
# [145] 💤 Menunggu 5 detik...
# [146] begitu datang ini langsung dicobain, semua berfungsi baik. s... → Pred: **Love** (3.80s) | Token: In=1212, Out=7 | RAM: 13.13 GB
# [146] 💤 Menunggu 5 detik...
# [147] Recommended Seller!! Respon cepat, pengiriman cukup cepat...... → Pred: **Happy** (4.07s) | Token: In=1166, Out=7 | RAM: 13.14 GB
# [147] 💤 Menunggu 5 detik...
# [148] jangan lupa gaes diorder toko ini... → Pred: **Happy** (3.32s) | Token: In=1163, Out=7 | RAM: 13.14 GB
# [148] 💤 Menunggu 5 detik...
# [149] Puas sih.. Recomended bukunya... → Pred: **Happy** (2.99s) | Token: In=1164, Out=7 | RAM: 13.14 GB
# [149] 💤 Menunggu 5 detik...
# [150] paaaaas banget ukurannya buat gantiin tempat sampah lama. ba... → Pred: **Love** (5.16s) | Token: In=1201, Out=7 | RAM: 13.15 GB
# [150] 💤 Menunggu 5 detik...
# [151] bagus bgt bukunya. suka. makasih... → Pred: **Love** (4.89s) | Token: In=1166, Out=7 | RAM: 13.12 GB
# [151] 💤 Menunggu 5 detik...
# [152] BAGUUUSSSS PACKING RAPUI, CEPAT SAMPAI, TERIMAKASIH SELLER..... → Pred: **Love** (4.16s) | Token: In=1184, Out=7 | RAM: 13.11 GB
# [152] 💤 Menunggu 5 detik...
# [153] check in nya gampang bgt, cuma kasih liat aja invoice sama K... → Pred: **Happy** (3.64s) | Token: In=1183, Out=7 | RAM: 13.11 GB
# [153] 💤 Menunggu 5 detik...
# [154] Bahannya adem. Warnanya cantik ??. Ukuran sesuai. terimakasi... → Pred: **Love** (6.16s) | Token: In=1173, Out=7 | RAM: 13.20 GB
# [154] 💤 Menunggu 5 detik...
# [155] Suka sama box nya ciamik dehhhhhhhhhhhhhhhhhhhhh... → Pred: **Love** (4.93s) | Token: In=1168, Out=7 | RAM: 13.20 GB
# [155] 💤 Menunggu 5 detik...
# [156] order yang ketiga. gercep. barang oke. pelayanan juga oke... → Pred: **Happy** (2.78s) | Token: In=1168, Out=7 | RAM: 13.19 GB
# [156] 💤 Menunggu 5 detik...
# [157] packing rapih, fast response, dan rgbnya juga bagus ??sangat... → Pred: **Love** (5.08s) | Token: In=1181, Out=7 | RAM: 13.12 GB
# [157] 💤 Menunggu 5 detik...
# [158] Selalu the best bgt deh... anabul ngga usah di train aja lan... → Pred: **Love** (5.06s) | Token: In=1175, Out=7 | RAM: 13.13 GB
# [158] 💤 Menunggu 5 detik...
# [159] mantappppppppppppppppppppppppppppppppp... → Pred: **Happy** (4.33s) | Token: In=1165, Out=7 | RAM: 13.13 GB
# [159] 💤 Menunggu 5 detik...
# [160] Build quality cakep,,stik normal smua,,pengiriman gak sampai... → Pred: **Love** (8.63s) | Token: In=1182, Out=7 | RAM: 13.13 GB
# [160] 💤 Menunggu 5 detik...
# [161] Produk yang diterima lengkap. Pas di kepala. Lampunya terang... → Pred: **Happy** (3.49s) | Token: In=1176, Out=7 | RAM: 13.13 GB
# [161] 💤 Menunggu 5 detik...
# [162] So far kualitas dan bentuk pellet paling bagus dari smua tok... → Pred: **Love** (4.48s) | Token: In=1185, Out=7 | RAM: 13.13 GB
# [162] 💤 Menunggu 5 detik...
# [163] Orderan yg ke 3 kali, selalu puas, unit bor nya mantap, sell... → Pred: **Love** (5.47s) | Token: In=1185, Out=7 | RAM: 13.14 GB
# [163] 💤 Menunggu 5 detik...
# [164] langganan beli minigold disini ??... → Pred: **Love** (6.22s) | Token: In=1163, Out=7 | RAM: 13.12 GB
# [164] 💤 Menunggu 5 detik...
# [165] suka banget sama original source yang mint... → Pred: **Love** (4.90s) | Token: In=1163, Out=7 | RAM: 13.14 GB
# [165] 💤 Menunggu 5 detik...
# [166] game lancar, kondisi box dan game cartridges mulus, pengirim... → Pred: **Love** (4.69s) | Token: In=1185, Out=7 | RAM: 13.16 GB
# [166] 💤 Menunggu 5 detik...
# [167] Mantapppp.Build qualitynya josss Pertahankan... → Pred: **Love** (3.61s) | Token: In=1166, Out=7 | RAM: 13.20 GB
# [167] 💤 Menunggu 5 detik...
# [168] mantap. pengiriman nya cepat banget. barang oke semua dan be... → Pred: **Love** (4.13s) | Token: In=1188, Out=7 | RAM: 13.27 GB
# [168] 💤 Menunggu 5 detik...
# [169] alhmdllh pkt ny dah smpe..ank2 seneng bgt klu Makan sama sar... → Pred: **Happy** (2.80s) | Token: In=1185, Out=7 | RAM: 13.28 GB
# [169] 💤 Menunggu 5 detik...
# [170] Pengiriman cepat dan aman. Barang sesuai deskripsi. Bagian u... → Pred: **Happy** (3.76s) | Token: In=1214, Out=7 | RAM: 13.28 GB
# [170] 💤 Menunggu 5 detik...
# [171] manchapppp.. sy suka. rekomen seller..... → Pred: **Love** (4.10s) | Token: In=1166, Out=7 | RAM: 13.27 GB
# [171] 💤 Menunggu 5 detik...
# [172] Mantap donk. Produk Original.... → Pred: **Happy** (3.14s) | Token: In=1162, Out=7 | RAM: 13.30 GB
# [172] 💤 Menunggu 5 detik...
# [173] mantul boskuhhh barang istimewa... → Pred: **Love** (5.01s) | Token: In=1165, Out=7 | RAM: 13.30 GB
# [173] 💤 Menunggu 5 detik...
# [174] Suka dengan bardi ini. Membantu banget matiin beberapa alat ... → Pred: **Love** (4.09s) | Token: In=1210, Out=7 | RAM: 13.30 GB
# [174] 💤 Menunggu 5 detik...
# [175] lucu bgt warnanya. recommended harga murah tapi ngga murahan... → Pred: **Love** (5.68s) | Token: In=1175, Out=7 | RAM: 13.33 GB
# [175] 💤 Menunggu 5 detik...
# [176] Respond seller cepat, pengiriman segera. Produk berkualitas.... → Pred: **Love** (3.70s) | Token: In=1169, Out=7 | RAM: 13.39 GB
# [176] 💤 Menunggu 5 detik...
# [177] mantappppp... → Pred: **Happy** (3.40s) | Token: In=1158, Out=7 | RAM: 13.39 GB
# [177] 💤 Menunggu 5 detik...
# [178] pohonnya masih segar, bonusnya juga banyak. makasih ya. udah... → Pred: **Happy** (4.00s) | Token: In=1177, Out=7 | RAM: 13.38 GB
# [178] 💤 Menunggu 5 detik...
# [179] Selalu bagus produknya, pembelian ke 2 Mantapp min, smoga la... → Pred: **Love** (4.38s) | Token: In=1173, Out=7 | RAM: 13.34 GB
# [179] 💤 Menunggu 5 detik...
# [180] Konsumen ga dianggap... Attitude merupakan hal pokok dan sem... → Pred: **Anger** (4.72s) | Token: In=1174, Out=8 | RAM: 13.34 GB
# [180] 💤 Menunggu 5 detik...
# [181] GA DIKASIH ADAPTOR GEPENG NYA. KETIPU SAYA... → Pred: **Anger** (4.44s) | Token: In=1175, Out=8 | RAM: 13.34 GB
# [181] 💤 Menunggu 5 detik...
# [182] packaging kurang rapih, semua kemasan produk BOLT sobek.. se... → Pred: **Sadness** (5.63s) | Token: In=1180, Out=8 | RAM: 13.34 GB
# [182] 💤 Menunggu 5 detik...
# [183] Rasanya ngadi2 sumpah, kayak pake saos sambel ?? kyk gapake ... → Pred: **Anger** (6.20s) | Token: In=1212, Out=8 | RAM: 13.35 GB
# [183] 💤 Menunggu 5 detik...
# [184] penjual gk respon bgt parah... → Pred: **Anger** (4.51s) | Token: In=1164, Out=8 | RAM: 13.35 GB
# [184] 💤 Menunggu 5 detik...
# [185] orng nnya responnya jutek bgt,, biasa aja kali, saya cm bert... → Pred: **Anger** (3.96s) | Token: In=1189, Out=8 | RAM: 13.29 GB
# [185] 💤 Menunggu 5 detik...
# [186] barang yg dikirim gk sesuai modelnya... → Pred: **Sadness** (4.81s) | Token: In=1163, Out=8 | RAM: 13.28 GB
# [186] 💤 Menunggu 5 detik...
# [187] Barang mau dikirim pakai ekspedisi ke luar kota tapi tidak d... → Pred: **Anger** (4.84s) | Token: In=1183, Out=8 | RAM: 13.27 GB
# [187] 💤 Menunggu 5 detik...
# [188] aromanya bikin pusing dan mual... → Pred: **Sadness** (3.71s) | Token: In=1163, Out=8 | RAM: 13.27 GB
# [188] 💤 Menunggu 5 detik...
# [189] lubang nya jelek bgt... → Pred: **Anger** (6.97s) | Token: In=1162, Out=8 | RAM: 13.26 GB
# [189] 💤 Menunggu 5 detik...
# [190] seller tidak bertanggung jawab. ????... → Pred: **Anger** (2.57s) | Token: In=1161, Out=8 | RAM: 13.25 GB
# [190] 💤 Menunggu 5 detik...
# [191] alamak....buset.packingnya kurang rapi...di bungkus plastik ... → Pred: **Anger** (5.60s) | Token: In=1187, Out=8 | RAM: 13.26 GB
# [191] 💤 Menunggu 5 detik...
# [192] bohong. Sama sekali tidak manjur.... → Pred: **Anger** (5.16s) | Token: In=1163, Out=8 | RAM: 13.26 GB
# [192] 💤 Menunggu 5 detik...
# [193] Beli 6 cuma dikirim 5, males complain ??... → Pred: **Sadness** (4.42s) | Token: In=1168, Out=8 | RAM: 13.26 GB
# [193] 💤 Menunggu 5 detik...
# [194] palsu ya. g berfungsi. bahan kasar dan sakit kalo dipakai.... → Pred: **Sadness** (5.13s) | Token: In=1169, Out=8 | RAM: 13.26 GB
# [194] 💤 Menunggu 5 detik...
# [195] Chatt, hampir Ga ada respond... → Pred: **Sadness** (2.67s) | Token: In=1162, Out=8 | RAM: 13.27 GB
# [195] 💤 Menunggu 5 detik...
# [196] kurang 1, penjual kurang teliti atau sengaja.... → Pred: **Sadness** (7.74s) | Token: In=1168, Out=8 | RAM: 13.26 GB
# [196] 💤 Menunggu 5 detik...
# [197] kualitas barang dibanding harga nya hanya so so lahh....pela... → Pred: **Anger** (5.16s) | Token: In=1251, Out=8 | RAM: 13.32 GB
# [197] 💤 Menunggu 5 detik...
# [198] lama banget sampenya..pas nyampe jamuran gini..haduuh..parah... → Pred: **Anger** (6.80s) | Token: In=1174, Out=8 | RAM: 13.34 GB
# [198] 💤 Menunggu 5 detik...
# [199] yg di pesan warna ngga sesuai klu memang ngga ada bilang aja... → Pred: **Anger** (5.65s) | Token: In=1183, Out=8 | RAM: 13.34 GB
# [199] 💤 Menunggu 5 detik...
# [200] Roti keras gak enak... → Pred: **Sadness** (3.33s) | Token: In=1160, Out=8 | RAM: 13.21 GB
# [200] 💤 Menunggu 5 detik...
# [201] udang red bee yg dipesan tdk ada,sdh dikomplain malah diteru... → Pred: **Sadness** (4.65s) | Token: In=1181, Out=8 | RAM: 13.23 GB
# [201] 💤 Menunggu 5 detik...
# [202] l2 r2 trigger nya ampas macam ***... → Pred: **Anger** (3.92s) | Token: In=1165, Out=8 | RAM: 13.24 GB
# [202] 💤 Menunggu 5 detik...
# [203] bocor!! paket basah, jd tinggal bublrwrap terikat isolasi aj... → Pred: **Anger** (5.98s) | Token: In=1192, Out=8 | RAM: 13.23 GB
# [203] 💤 Menunggu 5 detik...
# [204] Barang dateng pake kurir toko, di unboxing trnyt ad lecet/ba... → Pred: **Anger** (5.57s) | Token: In=1251, Out=8 | RAM: 13.22 GB
# [204] 💤 Menunggu 5 detik...
# [205] cepet rusak, kadang konek kadang engga... → Pred: **Sadness** (5.26s) | Token: In=1165, Out=8 | RAM: 13.22 GB
# [205] 💤 Menunggu 5 detik...
# [206] order minggu sampainya rabu, lambat nya minta ampuun, di tan... → Pred: **Anger** (4.93s) | Token: In=1203, Out=8 | RAM: 13.22 GB
# [206] 💤 Menunggu 5 detik...
# [207] BARANG TIDAK SESUAI PESANAN.. DIMINTA GOLD MALAH D KIRIM WAR... → Pred: **Anger** (5.03s) | Token: In=1184, Out=8 | RAM: 13.27 GB
# [207] 💤 Menunggu 5 detik...
# [208] SALAH ALAMAT. Sudah saya kirim chat bahwa minta dicancel utk... → Pred: **Anger** (3.57s) | Token: In=1228, Out=8 | RAM: 13.27 GB
# [208] 💤 Menunggu 5 detik...
# [209] DUANYA LAGI GOIB... → Pred: **Anger** (4.92s) | Token: In=1162, Out=8 | RAM: 13.27 GB
# [209] 💤 Menunggu 5 detik...
# [210] yg dikirim russakkkkk guys ampun dahh... → Pred: **Anger** (4.24s) | Token: In=1167, Out=8 | RAM: 13.27 GB
# [210] 💤 Menunggu 5 detik...
# [211] ga sesuai expetasi.....barang2 nya ga kuat.ukuran kcl kaya m... → Pred: **Sadness** (3.39s) | Token: In=1173, Out=8 | RAM: 13.24 GB
# [211] 💤 Menunggu 5 detik...
# [212] masa baru dateng langsung rusak... → Pred: **Sadness** (1.99s) | Token: In=1161, Out=8 | RAM: 13.24 GB
# [212] 💤 Menunggu 5 detik...
# [213] penyok, packingnya juga kurang aman... → Pred: **Sadness** (5.55s) | Token: In=1164, Out=8 | RAM: 13.25 GB
# [213] 💤 Menunggu 5 detik...
# [214] KIRIM PAKET GA NGOTAK.. RESOLUSI ARBITER TOKOPEDIA USELESS..... → Pred: **Anger** (5.86s) | Token: In=1179, Out=8 | RAM: 13.23 GB
# [214] 💤 Menunggu 5 detik...
# [215] barang kualitas jelek, kaki patah, banyak pecah sedikit dite... → Pred: **Anger** (6.14s) | Token: In=1188, Out=8 | RAM: 13.22 GB
# [215] 💤 Menunggu 5 detik...
# [216] packing hanya buble wrap, lain kali tambahkan kardus. komuni... → Pred: **Anger** (4.26s) | Token: In=1199, Out=8 | RAM: 13.24 GB
# [216] 💤 Menunggu 5 detik...
# [217] Susah bgt pasangnya!!! Gak kuat menahan airnya!!!... → Pred: **Anger** (4.66s) | Token: In=1169, Out=8 | RAM: 13.25 GB
# [217] 💤 Menunggu 5 detik...
# [218] Busa doank, tidak saya rekomendasikan... → Pred: **Sadness** (2.93s) | Token: In=1165, Out=8 | RAM: 13.24 GB
# [218] 💤 Menunggu 5 detik...
# [219] Chat tidak di balas, Kuota yang di janjikan 50gb nya tidak m... → Pred: **Anger** (4.87s) | Token: In=1183, Out=8 | RAM: 13.28 GB
# [219] 💤 Menunggu 5 detik...
# [220] Parah respon nya Butuh 4 hr sejak order baru dikirim Granola... → Pred: **Anger** (3.83s) | Token: In=1177, Out=8 | RAM: 13.29 GB
# [220] 💤 Menunggu 5 detik...
# [221] buruk super duper buruk kok bisa rusakk dlm nya ini pasti di... → Pred: **Anger** (3.79s) | Token: In=1200, Out=8 | RAM: 13.29 GB
# [221] 💤 Menunggu 5 detik...
# [222] kw kirim brg bekas dan rusak serta tdk menerima komplain kap... → Pred: **Anger** (4.31s) | Token: In=1181, Out=8 | RAM: 13.28 GB
# [222] 💤 Menunggu 5 detik...
# [223] Jualan kok ngotottt, nggak laku toko nya bang?... → Pred: **Anger** (4.08s) | Token: In=1169, Out=8 | RAM: 13.21 GB
# [223] 💤 Menunggu 5 detik...
# [224] bocor payahlah ga di periksa dulu... → Pred: **Anger** (4.50s) | Token: In=1165, Out=8 | RAM: 13.21 GB
# [224] 💤 Menunggu 5 detik...
#
# ==================================================
# === 📊 Ringkasan Evaluasi ===
# ==================================================
# Total sampel diproses: 223 dari 225
# Total waktu uji coba : 2235.57 detik
# Rata-rata latency: **4.82 detik/sampel** (tanpa warm-up)
# Throughput: **12.46 sampel/menit** (tanpa warm-up)
# --------------------------------------------------
# Rata-rata Prompt Tokens: 1182
# Rata-rata Completion Tokens: 8
# --------------------------------------------------
# Rata-rata RAM: 13.24 GB
# Rata-rata VRAM: 0.00 GB
# ==================================================
#
# ✅ Hasil disimpan ke: **results_metrics_emotion.csv**

# %%
import os
import json
import time
from dotenv import load_dotenv, find_dotenv
from google import genai
from google.genai import types
from google.genai.errors import APIError

# ==========================================================
# Load API Key
# ==========================================================
dotenv_path = find_dotenv(usecwd=True, raise_error_if_not_found=False)
if dotenv_path:
    load_dotenv(dotenv_path=dotenv_path)

client = genai.Client(api_key=os.getenv("GEMINI_API_KEY"))
model_name = "gemini-2.5-flash"

emotion_labels = ["Anger", "Fear", "Happy", "Love", "Sadness"]

# ==========================================================
# MASUKKAN TEKS YANG INGIN DIPREDIKSI
# ==========================================================
sample_text = "untuk jepit ke mejanya loss. ga bisa ngunci. sudah di coba dengan SEAL TAPE. tapi terlalu longgar sehingga tidak bisa nge lock. untuk boom arm nya bagus. sayang jadi bingung pakenya karna ga bisa ngelock"

# ==========================================================
# Prompt System
# ==========================================================
system_prompt = """
    Anda adalah asisten AI yang ahli dalam analisis emosi pada teks Bahasa Indonesia. 
    Tugas Anda adalah mengklasifikasikan teks pengguna ke dalam salah satu dari 
    5 kelas emosi berikut: Anger, Fear, Happy, Love, dan Sadness.

    Gunakan panduan karakteristik berikut:

    1. ANGER
    - Mengandung kata kasar atau makian.
    - Menunjukkan kemarahan, kekesalan, atau kebencian.
    - Keluhan atau ketidaksukaan terhadap produk/layanan/pengiriman.
    - Menggunakan huruf kapital berlebihan atau tanda baca marah (“!!!”, “???”).
    - Ekspresi jengkel, sebel, atau benci.

    2. FEAR
    - Kalimat peringatan atau rasa takut.
    - Kekhawatiran terhadap produk atau penjual.
    - Keraguan, ketidakpastian, atau menanyakan hal yang membuat cemas.
    - Ekspresi hati-hati, waspada, curiga, atau ragu terhadap keamanan.

    3. HAPPY
    - Mengandung pujian.
    - Kepuasan terhadap produk/penjual.
    - Ekspresi senang, gembira, bahagia, atau puas.
    - Bangga dan memberikan penilaian positif terhadap kualitas produk/penjual.

    4. LOVE
    - Ekspresi perasaan sayang, suka, atau rasa cinta.
    - Sangat puas terhadap produk.
    - Mengandung ungkapan hiperbola/“berlebihan” untuk menyanjung.
    - Mengandung pujian kuat atau kekaguman mendalam.
    - Ekspresi bangga atau sangat menyukai produk/penjual.

    5. SADNESS
    - Menyatakan kekecewaan terhadap produk.
    - Penyesalan, sedih, atau tidak puas.
    - Ekspresi kecewa, menyesal, atau merasa dirugikan.

    Keluaran Anda HARUS berupa JSON dengan format:
    {"emosi": "<Anger/Fear/Happy/Love/Sadness>"}
    """

# ==========================================================
# Few-shots (disingkat dari script Anda)
# ==========================================================
few_shot_examples = """
    Berikut adalah 10 contoh kasus klasifikasi emosi (10-SHOTS) beserta output JSON yang diharapkan. Model HARUS mengikuti format ini:

    --- Contoh 1 (Fear) ---
    Teks ulasan: "Barang tidak sesuai dengan yg di iklankan seperti nya bekas"
    Output: {"emosi": "Fear"}

    --- Contoh 2 (Fear) ---
    Teks ulasan: "Respon seller bagus tapi produknya tidak, suaranya kecil masih kalah dengan mic hp internal. Harga sangat tidak sesuai dengan kualitas"
    Output: {"emosi": "Fear"}
    
    --- Contoh 3 (Happy) ---
    Teks ulasan: "pengiriman cepat, packing rapi, kualitas mantap"
    Output: {"emosi": "Happy"}

    --- Contoh 4 (Happy) ---
    Teks ulasan: "Bagus, berkualitas, sesuai gbr. Makasih Seller, Tokped dan Kurir"
    Output: {"emosi": "Happy"}

    --- Contoh 5 (Anger) ---
    Teks ulasan: "Barang Rusak , Ga Guna Sama Sekali ... Parah"
    Output: {"emosi": "Anger"}

    --- Contoh 6 (Anger) ---
    Teks ulasan: "barang bosok! sekali Pake rusak.. mau claim dijawab berbelit ama adminnya"
    Output: {"emosi": "Anger"}

    --- Contoh 7 (Love) ---
    Teks ulasan: "Bagus banget keyboardnya. Packing sangat aman karena double kardus. Warna juga keren."
    Output: {"emosi": "Love"}

    --- Contoh 8 (Love) ---
    Teks ulasan: "Lucuu bangett.. Pengirimannya cepat, sellernya responsif banget.. Subuh2 di chat jg dijawab soalnya aku liat ini uda dr malam banget sih.. Kirain bakal baru dijawab agak siang.. Trnyata subuh uda dijawab?? informatif banget.. Ngsh tau klo dikasih oil agak berkabut.. Kirain bakal lbh berkabut dr ini.. Trnyata kabutnya cm kyk difoto.. Seneng deh.. Lampunya jg terang klo di tmpt gelap ?? makasihh yaa"
    Output: {"emosi": "Love"}

    --- Contoh 9 (Sadness) ---
    Teks ulasan: "Kecewa parah nggk berkah jualan gitu"
    Output: {"emosi": "Sadness"}

    --- Contoh 10 (Sadness) ---
    Teks ulasan: "Yg bikin kecewa pesen 6 items yg nyampe cuma satu. Masih saya tunggu kekurangan barangnya UNO STACKO KAYU, uno card 2pcs dan werewolf 2pcs. Kalau tidak tolong refund aja uangnya."
    Output: {"emosi": "Sadness"}

    Klasifikasikan teks ulasan baru di bawah berdasarkan konteks 10 contoh di atas.
    """

# ==========================================================
# User Prompt
# ==========================================================
user_prompt = f"""
    {few_shot_examples}
    
    Teks ulasan berikut: 
    "{sample_text}"

    Klasifikasikan teks tersebut ke dalam salah satu emosi berikut:
    {', '.join(emotion_labels)}.
    """

messages = [
    types.Content(role="user", parts=[types.Part(text=user_prompt)])
]

config = types.GenerateContentConfig(
    system_instruction=system_prompt,
    response_mime_type="application/json",
    response_schema={
        "type": "object",
        "properties": {
            "emosi": {"type": "string"}
        }
    }
)

# ==========================================================
# PREDIKSI
# ==========================================================
try:
    t0 = time.time()
    response = client.models.generate_content(
        model=model_name,
        contents=messages,
        config=config
    )
    latency = time.time() - t0

    json_raw = response.text.strip()
    result = json.loads(json_raw)

    predicted = result.get("emosi", "").capitalize()
    if predicted not in emotion_labels:
        predicted = "Neutral"

    print("\n==============================")
    print("       HASIL PREDIKSI")
    print("==============================")
    print("Teks:", sample_text)
    print("Prediksi Emosi:", predicted)
    print(f"Latency: {latency:.2f} detik")

    if response.usage_metadata:
        print(f"Prompt Tokens: {response.usage_metadata.prompt_token_count}")
        print(f"Output Tokens: {response.usage_metadata.candidates_token_count}")

    print("==============================\n")

except APIError as e:
    print("❌ API Error:", e)
except Exception as e:
    print("❌ Unexpected Error:", e)
# Out:
# ==============================
#        HASIL PREDIKSI
# ==============================
# Teks: untuk jepit ke mejanya loss. ga bisa ngunci. sudah di coba dengan SEAL TAPE. tapi terlalu longgar sehingga tidak bisa nge lock. untuk boom arm nya bagus. sayang jadi bingung pakenya karna ga bisa ngelock
# Prediksi Emosi: Sadness
# Latency: 5.12 detik
# Prompt Tokens: 1205
# Output Tokens: 8
# ==============================

# %%
results_df = pd.read_csv('results_metrics_emotion.csv')

# %%
import pandas as pd

# Load data
df = pd.read_csv("results_metrics_emotion.csv")

# Ambil latency per sampel (detik)
latencies = df["latency_sec"].values

# Jumlah sampel
N = len(latencies)

# ------------------------
# LATENCY (Persamaan 5)
# ------------------------
avg_latency = latencies.sum() / N  # detik per sampel

# ------------------------
# THROUGHPUT (Persamaan 6)
# ------------------------
T_seconds = latencies.sum()        # total waktu pemrosesan (detik)
throughput_per_minute = (N / T_seconds) * 60

print(f"Jumlah sampel (N): {N}")
print(f"Rata-rata latency (s/sample): {avg_latency:.2f}")
print(f"Throughput (sample/minute): {throughput_per_minute:.2f}")
# Out:
# Jumlah sampel (N): 225
# Rata-rata latency (s/sample): 4.80
# Throughput (sample/minute): 12.50

# %%
y_true = results_df["actual"]
y_pred = results_df["predicted"]

# %%
report = classification_report(y_true, y_pred, digits=2, zero_division=0)
print("\n=== CLASSIFICATION REPORT ===")
print(report)
# Out:
# === CLASSIFICATION REPORT ===
#               precision    recall  f1-score   support
#
#        Anger       0.57      0.69      0.63        45
#         Fear       0.67      0.09      0.16        45
#        Happy       0.72      0.80      0.76        45
#         Love       0.83      0.67      0.74        45
#      Sadness       0.47      0.82      0.60        45
#
#     accuracy                           0.61       225
#    macro avg       0.65      0.61      0.58       225
# weighted avg       0.65      0.61      0.58       225

# %%
accuracy = accuracy_score(y_true, y_pred)
precision_avg = precision_score(y_true, y_pred, average="macro", zero_division=0)
recall_avg = recall_score(y_true, y_pred, average="macro", zero_division=0)
f1_avg = f1_score(y_true, y_pred, average="macro", zero_division=0)

# %%
print(f"Precision avg : {precision_avg:.2f}")
print(f"Recall avg : {recall_avg:.2f}")
print(f"F1 avg : {f1_avg:.2f}")
print(f"Akurasi : {accuracy:.2f}")
# Out:
# Precision avg : 0.65
# Recall avg : 0.61
# F1 avg : 0.58
# Akurasi : 0.61

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# === Buat confusion matrix ===
cm = confusion_matrix(y_true, y_pred, labels=['Anger', 'Fear', 'Happy', 'Love', 'Sadness'])

# === Plot heatmap ===
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='YlGnBu',
            xticklabels=['Anger', 'Fear', 'Happy', 'Love', 'Sadness'],
            yticklabels=['Anger', 'Fear', 'Happy', 'Love', 'Sadness'])

plt.title("Confusion Matrix - LLM Gemini 2.5 Flash (10-Shot Emotion Classification)")
plt.xlabel("Predicted Emotion")
plt.ylabel("True Emotion")
plt.tight_layout()
plt.savefig("confusion_matrix_emotion_llm.png", dpi=300)
print("✅ Confusion matrix disimpan di 'confusion_matrix_emotion_llm.png'")
plt.show()
# Out:
# ✅ Confusion matrix disimpan di 'confusion_matrix_emotion_llm.png'
